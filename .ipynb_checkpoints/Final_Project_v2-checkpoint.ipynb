# %% [markdown]
# # Data Science Final Project

# %% [markdown]
# # Introduction

# %% [markdown]
# In this project, I aim to further the analysis for my arts and jobs paper. The overall research question is: what drives growth, jobs or amenities? Do people follow jobs or amenities or both?
#
# Using regression analysis in the previous paper, I found that arts are drivers of growth. However, it is stronger in some places than others; for example, in more populated areas, or areas with more college graduates. But what really are the underelying variables that would distinguish the influence of the arts in one places than in others? What variables would be more relevant in the jobs and amenities to explain growth? In other words, <b> why are arts where they are?</b>
#
# With over 50 control variables available, I would like to know which ones would help describe the changes better than only the main regression variables. And here I use some methods to see what variables could explain the impact of the arts on the growth of jobs.

# %%
#Loading the packages

# %matplotlib inline
from collections import Counter
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans, DBSCAN
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import linear_model, metrics

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# # The Data

# %% [markdown]
# The main data show the number of arts and non-arts jobs per zip code. The data is from the County Business Patterns, from the Census, and data ranges from 1998 to 2014.

# %%
#Loading the datafile. This is just a sample of the data. N=500
df = pd.read_csv("nomiss_sample.csv")

# Dropping unnecessary variables (Some string variables too, like names of the zip code location)
df.drop(['pctba90', 'racediversity90', 'medrent90', 'medhhinc90', 'meantrav90', 'meanlengthres90', 'pctsamehouse90',
'pctfemale90', 'pctmarried90', 'pctchild90', 'pctunemp90', 'diversityanc90', 'pctrental90', 'pctpov90', 'pctbike90',
'pctdrove90', 'pctwalk90', 'density1990', 'housingdensity1990', 'Pop1990', 'Unnamed: 0','JobsT_1998', 'ArtsW_1998', 'JobsW_1998', 
'ArtSupport_1998', 'JobsT_1999', 'ArtsW_1999', 'JobsW_1999', 'ArtSupport_1999', 'JobsT_2000', 'ArtsW_2000', 'JobsW_2000',
 'ArtSupport_2000', 'JobsT_2001', 'ArtsW_2001', 'JobsW_2001', 'ArtSupport_2001', 'JobsT_2002', 'ArtsW_2002', 'JobsW_2002',
 'ArtSupport_2002', 'JobsT_2003', 'ArtsW_2003', 'JobsW_2003', 'ArtSupport_2003', 'JobsT_2004', 'ArtsW_2004', 'JobsW_2004',
 'ArtSupport_2004', 'JobsT_2005', 'ArtsW_2005', 'JobsW_2005', 'ArtSupport_2005', 'JobsT_2006', 'ArtsW_2006', 'JobsW_2006',
 'ArtSupport_2006', 'JobsT_2007', 'ArtsW_2007', 'JobsW_2007', 'ArtSupport_2007', 'JobsT_2008', 'ArtsW_2008', 'JobsW_2008',
 'ArtSupport_2008', 'JobsT_2009', 'ArtsW_2009', 'JobsW_2009', 'ArtSupport_2009', 'JobsT_2010', 'ArtsW_2010', 'JobsW_2010',
 'ArtSupport_2010', 'JobsT_2011', 'ArtsW_2011', 'JobsW_2011', 'ArtSupport_2011', 'JobsT_2012', 'ArtsW_2012', 'JobsW_2012',
 'ArtSupport_2012', 'JobsT_2013', 'ArtsW_2013', 'JobsW_2013', 'ArtSupport_2013', 'JobsT_2014', 'ArtsW_2014',
 'JobsW_2014', 'ArtSupport_2014', 'ARTGOSLG98', 'RentMed', 'City', 'State', 'Location', 'zipcode'], axis=1, inplace=True)

# Creating change variable for arts
df['arts_change'] = df['ArtsN_2014'] - df['ArtsN_1998']

# Creating change variable for jobs
df['jobs_change'] = df['ArtsN_2014'] - df['ArtsN_1998']

# %%
#Listing the variables in the data.b
list(df.columns.values)
# Out:
# ['zip',
#  'ArtsN_1998',
#  'JobsN_1998',
#  'ArtsN_1999',
#  'JobsN_1999',
#  'ArtsN_2000',
#  'JobsN_2000',
#  'ArtsN_2001',
#  'JobsN_2001',
#  'ArtsN_2002',
#  'JobsN_2002',
#  'ArtsN_2003',
#  'JobsN_2003',
#  'ArtsN_2004',
#  'JobsN_2004',
#  'ArtsN_2005',
#  'JobsN_2005',
#  'ArtsN_2006',
#  'JobsN_2006',
#  'ArtsN_2007',
#  'JobsN_2007',
#  'ArtsN_2008',
#  'JobsN_2008',
#  'ArtsN_2009',
#  'JobsN_2009',
#  'ArtsN_2010',
#  'JobsN_2010',
#  'ArtsN_2011',
#  'JobsN_2011',
#  'ArtsN_2012',
#  'JobsN_2012',
#  'ArtsN_2013',
#  'JobsN_2013',
#  'ArtsN_2014',
#  'JobsN_2014',
#  'MedAge2k',
#  'pctba2k',
#  'racediversity2k',
#  'medrent2k',
#  'medhhinc2k',
#  'meantrav2k',
#  'medlengthres2k',
#  'pctsamehouse2k',
#  'pctfemale2k',
#  'pctmarried2k',
#  'pctchild2k',
#  'pctunemp2k',
#  'diversityfb2k',
#  'pctrental2k',
#  'pctpov2k',
#  'pctbike2k',
#  'pctdrove2k',
#  'pctwalk2k',
#  'density2000',
#  'housingdensity2000',
#  'Pop2000',
#  'Democ92',
#  'NonWhite_90',
#  'CollProfLv90',
#  'CrimeRate1999county',
#  'Traditionalistic',
#  'Self_Expressive',
#  'Utilitarian',
#  'Charismatic',
#  'Egalitarian',
#  'Neighborly',
#  'Formality',
#  'Exhibitionism',
#  'Glamorous',
#  'Transgressive',
#  'Rational',
#  'Locality',
#  'State_Scenes',
#  'Corporateness',
#  'Ethnicity',
#  'arts_change',
#  'jobs_change']

# %% [markdown]
# ## Defining the variables

# %%
# Defining core variables 

core = ['Pop2000', 'CrimeRate1999county', 'Democ92', 'NonWhite_90', 'CollProfLv90']

# Defining scenes variables

scenes = ['Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 'Neighborly', 'Formality',
'Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 'Corporateness', 'Ethnicity']

# Defining Geolytics variables 

geo = ['MedAge2k', 'pctba2k', 'racediversity2k', 'medrent2k', 'medhhinc2k', 'meantrav2k', 'medlengthres2k',
 'pctsamehouse2k', 'pctfemale2k', 'pctmarried2k', 'pctchild2k', 'pctunemp2k', 'diversityfb2k', 'pctrental2k',
 'pctpov2k', 'pctbike2k', 'pctdrove2k', 'pctwalk2k', 'density2000', 'housingdensity2000']

# Geolytics and core 

geo_core = ['MedAge2k', 'pctba2k', 'racediversity2k', 'medrent2k', 'medhhinc2k', 'meantrav2k', 'medlengthres2k',
 'pctsamehouse2k', 'pctfemale2k', 'pctmarried2k', 'pctchild2k', 'pctunemp2k', 'diversityfb2k', 'pctrental2k',
 'pctpov2k', 'pctbike2k', 'pctdrove2k', 'pctwalk2k', 'density2000', 'housingdensity2000', 
 'Pop2000', 'CrimeRate1999county', 'Democ92', 'NonWhite_90', 'CollProfLv90']

# Defining Arts and Jobs variables 

arts_jobs = ['ArtsN_1998', 'JobsN_1998', 'ArtsN_1999', 'JobsN_1999', 'ArtsN_2000', 'JobsN_2000', 'ArtsN_2001', 'JobsN_2001',
 'ArtsN_2002', 'JobsN_2002', 'ArtsN_2003', 'JobsN_2003', 'ArtsN_2004', 'JobsN_2004', 'ArtsN_2005', 'JobsN_2005',
 'ArtsN_2006', 'JobsN_2006', 'ArtsN_2007', 'JobsN_2007', 'ArtsN_2008', 'JobsN_2008', 'ArtsN_2009', 'JobsN_2009',
 'ArtsN_2010', 'JobsN_2010', 'ArtsN_2011', 'JobsN_2011', 'ArtsN_2012', 'JobsN_2012', 'ArtsN_2013', 'JobsN_2013']

# Defining all variables

all_var = ['Pop2000', 'CrimeRate1999county', 'Democ92', 'NonWhite_90', 'CollProfLv90', 'Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 'Neighborly', 'Formality',
'Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 'Corporateness', 'Ethnicity', 'MedAge2k', 'pctba2k', 'racediversity2k', 'medrent2k', 'medhhinc2k', 'meantrav2k', 'medlengthres2k',
 'pctsamehouse2k', 'pctfemale2k', 'pctmarried2k', 'pctchild2k', 'pctunemp2k', 'diversityfb2k', 'pctrental2k',
 'pctpov2k', 'pctbike2k', 'pctdrove2k', 'pctwalk2k', 'density2000', 'housingdensity2000', 'ArtsN_1998', 'JobsN_1998', 'ArtsN_1999', 'JobsN_1999', 'ArtsN_2000', 'JobsN_2000', 'ArtsN_2001', 'JobsN_2001',
 'ArtsN_2002', 'JobsN_2002', 'ArtsN_2003', 'JobsN_2003', 'ArtsN_2004', 'JobsN_2004', 'ArtsN_2005', 'JobsN_2005',
 'ArtsN_2006', 'JobsN_2006', 'ArtsN_2007', 'JobsN_2007', 'ArtsN_2008', 'JobsN_2008', 'ArtsN_2009', 'JobsN_2009',
 'ArtsN_2010', 'JobsN_2010', 'ArtsN_2011', 'JobsN_2011', 'ArtsN_2012', 'JobsN_2012', 'ArtsN_2013', 'JobsN_2013']

# %% [markdown]
# ## What are the arts?
#
# The arts are defined as sum of the number of jobs in the following categories:
#
# <img src="Categories.png" alt="Categories">
#
# But here I only focus on the narrow categories.

# %%
#Number of observations, number of variables

df.shape
# Out:
# (500, 77)

# %% [markdown]
# ### Variables

# %% [markdown]
# Below is the data description of the 2014 <b> main variables </b> for the arts and non-arts jobs.

# %%
df.describe()
# Out:
#                 zip   ArtsN_1998    JobsN_1998   ArtsN_1999    JobsN_1999  \
# count    500.000000   500.000000    500.000000   500.000000    500.000000
# mean   48128.890000   130.640000   8955.114000   139.458000   9189.832000
# std    29429.254671   266.646889  10047.951921   283.630317  10304.383891
# min     1001.000000     3.000000     51.000000     3.000000     35.000000
# 25%    21648.500000    18.000000   2272.250000    18.000000   2334.000000
# 50%    45205.500000    61.000000   5929.000000    62.000000   6067.000000
# 75%    75188.500000   138.250000  11861.750000   151.500000  12362.500000
# max    99574.000000  2906.000000  77711.000000  3038.000000  79736.000000
#
#         ArtsN_2000    JobsN_2000   ArtsN_2001    JobsN_2001   ArtsN_2002  \
# count   500.000000    500.000000   500.000000    500.000000   500.000000
# mean    138.208000   9388.934000   147.424000   9351.760000   142.806000
# std     273.859597  10557.476619   290.826113  10423.508287   272.958049
# min       3.000000     65.000000     3.000000     51.000000     3.000000
# 25%      18.000000   2434.750000    19.000000   2458.000000    18.000000
# 50%      63.500000   6016.500000    68.500000   6104.000000    62.000000
# 75%     150.000000  12499.750000   165.000000  12479.500000   162.250000
# max    3025.000000  83091.000000  3570.000000  75814.000000  2765.000000
#
#           ...       Exhibitionism   Glamorous  Transgressive    Rational  \
# count     ...          500.000000  500.000000     500.000000  500.000000
# mean      ...            3.137102    3.081862       2.738596    2.977782
# std       ...            0.045165    0.048666       0.064297    0.057837
# min       ...            2.916667    2.888889       2.386364    2.787879
# 25%       ...            3.108905    3.053571       2.700000    2.942790
# 50%       ...            3.137995    3.081550       2.742361    2.972536
# 75%       ...            3.166667    3.106890       2.778146    3.001490
# max       ...            3.295455    3.346154       2.944444    3.309091
#
#          Locality  State_Scenes  Corporateness   Ethnicity  arts_change  \
# count  500.000000    500.000000     500.000000  500.000000   500.000000
# mean     3.027992      2.883765       3.060128    2.984152    44.692000
# std      0.054236      0.089126       0.072830    0.016829   229.471575
# min      2.897297      2.295455       2.700000    2.818182 -2046.000000
# 25%      2.992405      2.842299       3.021979    2.978701    -9.000000
# 50%      3.022582      2.902187       3.064773    2.987509     8.500000
# 75%      3.056452      2.945034       3.107924    2.994923    70.000000
# max      3.500000      3.115385       3.233333    3.010204  3123.000000
#
#        jobs_change
# count   500.000000
# mean     44.692000
# std     229.471575
# min   -2046.000000
# 25%      -9.000000
# 50%       8.500000
# 75%      70.000000
# max    3123.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# Some of the main <b> control variables </b> are listed below. The first table shows the core variables, which are from Prof. Clark's Scenes Project.

# %% [markdown]
# | Variable | Description  |
# |------|------|
# | Pop2000 | Population in 2000 |
# | CrimeRate1999county | Crime Rate in 1999 |
# | Democ92 | Percent Democrats |
# | RentMed | Median Rent |
# | NonWhite_90 | Percent non white population in 1990 |
# | CollProfLv90 | Percent college graduates in 1990 |

# %%
# Describing the variables
df[core].describe()
# Out:
#            Pop2000  CrimeRate1999county     Democ92   NonWhite_90  \
# count     500.0000           500.000000  500.000000    500.000000
# mean    20120.7880          4149.794000   41.086000   3337.730000
# std     16187.0679          2039.368885    9.530315   6101.702711
# min       200.0000           151.000000    0.000000      0.000000
# 25%      7573.7500          2652.000000   34.900000    195.500000
# 50%     16713.0000          3828.500000   39.750000    901.000000
# 75%     27885.0000          5566.750000   47.400000   3450.000000
# max    114124.0000         13998.000000   72.400000  61454.000000
#
#        CollProfLv90
# count    500.000000
# mean       0.217761
# std        0.131364
# min        0.017610
# 25%        0.121331
# 50%        0.178273
# 75%        0.283603
# max        0.914747

# %%
# Correlation of the variables
df[core].corr()
# Out:
#                       Pop2000  CrimeRate1999county   Democ92  NonWhite_90  \
# Pop2000              1.000000             0.263818  0.226542     0.616744
# CrimeRate1999county  0.263818             1.000000  0.318003     0.257733
# Democ92              0.226542             0.318003  1.000000     0.333987
# NonWhite_90          0.616744             0.257733  0.333987     1.000000
# CollProfLv90         0.037704             0.040056  0.124377    -0.115296
#
#                      CollProfLv90
# Pop2000                  0.037704
# CrimeRate1999county      0.040056
# Democ92                  0.124377
# NonWhite_90             -0.115296
# CollProfLv90             1.000000

# %% [markdown]
# The table below shows the <b> Scenes variables </b>, which are decoded into 15 dimensions. These variables were created by coders, who gave a score from 1 to 5 on each dimension based on the type of neighborhood (zip code) they were analyzing, and them summed. The coders followed a series of guidelines, but mostly trying to answer the question: <b> does an amenity’s vitality and energy comes from the way it embodies this sub-category? </b> Thus, coding whether an amenity positively or negatively indicated the concrete presence of the sub-category.
#
# The AP variables reflect "amenities performance", on the zip code level.

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)

correlations = df[core].corr()
print correlations
print sns.heatmap(correlations, cmap=cmap)
# Out:
#                       Pop2000  CrimeRate1999county   Democ92  NonWhite_90  \
# Pop2000              1.000000             0.263818  0.226542     0.616744
# CrimeRate1999county  0.263818             1.000000  0.318003     0.257733
# Democ92              0.226542             0.318003  1.000000     0.333987
# NonWhite_90          0.616744             0.257733  0.333987     1.000000
# CollProfLv90         0.037704             0.040056  0.124377    -0.115296
#
#                      CollProfLv90
# Pop2000                  0.037704
# CrimeRate1999county      0.040056
# Democ92                  0.124377
# NonWhite_90             -0.115296
# CollProfLv90             1.000000
# Axes(0.125,0.125;0.62x0.775)

# %% [markdown]
# | Scenes Dimension | Type | Measurement Level | Description (Values) |
# |------|------|
#  | Traditionalistic | Numeric | Scale | Appeals to heritage and the past |
#  | Self_expressive | Numeric | Scale | Unique, personal, expression |
# | Utilitarian | Numeric | Scale | Usefulness of its amenities |
# | Charismatic | Numeric | Scale | In the presence of an exceptional personality |
#  | Egalitarian | Numeric | Scale | Universal equality, treating others non-strategically |
#  | Neighborly | Numeric | Scale | Closeness, personal networks, face-to-face interactions |
#  | Formality | Numeric | Scale | Fitting into established patterns of social etiquette |
# | Exhibitionism | Numeric | Scale | Encourage looking at others and being looked by them in turn |
#  | Glamorous | Numeric | Scale | Charm, allure, star power, status |
#  | Transgressive | Numeric | Scale | Revel in shocking others and associating with equally shocking others |
#  | Rational | Numeric | Scale | Power to choose one's own fate (organic or planned growth)|
# | Locality | Numeric | Scale | Feeling rooted in a place |
# | State | Numeric | Scale | Role of the State in shaping one's identity |
#  | Corporateness | Numeric | Scale | Corporations as social power that shape identity |
#  | Ethnicity | Numeric | Scale | Shape of pre-reflective identity |

# %%
df[scenes].describe()
# Out:
#        Traditionalistic  Self_Expressive  Utilitarian  Charismatic  \
# count        500.000000       500.000000   500.000000   500.000000
# mean           3.048148         3.081265     2.787930     3.149721
# std            0.026183         0.060989     0.105312     0.045007
# min            2.974324         2.918269     2.272727     3.000000
# 25%            3.033345         3.042018     2.733190     3.124302
# 50%            3.044672         3.078252     2.789004     3.147118
# 75%            3.060032         3.116755     2.845931     3.169700
# Egalitarian          1.000000    0.852908  -0.082950       0.171654
# Neighborly           0.852908    1.000000  -0.044564       0.256496
# Formality           -0.082950   -0.044564   1.000000      -0.192812
# Exhibitionism        0.171654    0.256496  -0.192812       1.000000
# Glamorous            0.025868    0.140571   0.107416       0.464187
# Transgressive       -0.629670   -0.641304  -0.261823      -0.083907
# Rational            -0.368802   -0.294637   0.488806      -0.289099
# Locality             0.239735    0.322211  -0.201983      -0.117185
# State_Scenes        -0.907871   -0.872471   0.069571      -0.236687
# Corporateness       -0.768046   -0.772318   0.289313      -0.267643
# Ethnicity            0.268871    0.130070  -0.157677       0.090551
#
#                   Glamorous  Transgressive  Rational  Locality  State_Scenes  \
# Traditionalistic  -0.051257      -0.561750 -0.501419  0.347655     -0.701196
# Self_Expressive    0.504501       0.285856 -0.053546 -0.100305      0.377549
# Utilitarian       -0.284560       0.236469  0.601431 -0.298943      0.560367
# Charismatic        0.310493      -0.342675 -0.336804  0.001033     -0.603599
# Egalitarian        0.025868      -0.629670 -0.368802  0.239735     -0.907871
# Neighborly         0.140571      -0.641304 -0.294637  0.322211     -0.872471
# Formality          0.107416      -0.261823  0.488806 -0.201983      0.069571
# Exhibitionism      0.464187      -0.083907 -0.289099 -0.117185     -0.236687
# Glamorous          1.000000      -0.245902 -0.091829 -0.151604     -0.143862
# Transgressive     -0.245902       1.000000  0.213118 -0.152304      0.646286
# Rational          -0.091829       0.213118  1.000000 -0.177643      0.459189
# Locality          -0.151604      -0.152304 -0.177643  1.000000     -0.184295
# State_Scenes      -0.143862       0.646286  0.459189 -0.184295      1.000000
# Corporateness      0.108623       0.278050  0.401512 -0.484518      0.701862
# Ethnicity         -0.121182      -0.206105 -0.591446  0.381451     -0.216645
#
#                   Corporateness  Ethnicity
# Traditionalistic      -0.625846   0.409693
# Self_Expressive        0.270652  -0.078146
# Utilitarian            0.618676  -0.415390
# Charismatic           -0.431175   0.075853
# Egalitarian           -0.768046   0.268871
# Neighborly            -0.772318   0.130070
# Formality              0.289313  -0.157677
# Exhibitionism         -0.267643   0.090551
# Glamorous              0.108623  -0.121182
# Transgressive          0.278050  -0.206105
# Rational               0.401512  -0.591446
# Locality              -0.484518   0.381451
# State_Scenes           0.701862  -0.216645
# Corporateness          1.000000  -0.367468
# Ethnicity             -0.367468   1.000000
# Axes(0.125,0.125;0.62x0.775)

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='Traditionalistic', y='ArtsN_2014', ax=axs[0], figsize=(16, 8))
df.plot(kind='scatter', x='Self_Expressive', y='ArtsN_2014', ax=axs[1])
df.plot(kind='scatter', x='Utilitarian', y='ArtsN_2014', ax=axs[2])

fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='Charismatic', y='ArtsN_2014', ax=axs[0], figsize=(16, 8))
df.plot(kind='scatter', x='Egalitarian', y='ArtsN_2014', ax=axs[1])
df.plot(kind='scatter', x='Neighborly', y='ArtsN_2014', ax=axs[2])

fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='Formality', y='ArtsN_2014', ax=axs[0], figsize=(16, 8))
df.plot(kind='scatter', x='Exhibitionism', y='ArtsN_2014', ax=axs[1])
df.plot(kind='scatter', x='Glamorous', y='ArtsN_2014', ax=axs[2])

fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='Transgressive', y='ArtsN_2014', ax=axs[0], figsize=(16, 8))
df.plot(kind='scatter', x='Rational', y='ArtsN_2014', ax=axs[1])
df.plot(kind='scatter', x='Locality', y='ArtsN_2014', ax=axs[2])

fig, axs = plt.subplots(1, 3, sharey=True)
df.plot(kind='scatter', x='State_Scenes', y='ArtsN_2014', ax=axs[0], figsize=(16, 8))
df.plot(kind='scatter', x='Corporateness', y='ArtsN_2014', ax=axs[1])
df.plot(kind='scatter', x='Ethnicity', y='ArtsN_2014', ax=axs[2])

# %% [markdown]
# PS: The scenes variables are highly correlated. May be causing some multicollinearity on the analysis. <br/>
# I am asking my advisor why and if we have better data...

# %% [markdown]
# Other variables of interest are from the <b> Geolytics database </b>, also in the zip code level. Some variables are described in the table below.

# %% [markdown]
# | Variable | Type | Measurement Level | Description  |
# |------|------|
# | pctba2k  | Numeric | Scale | Percent Graduated Bachelor Degree in 2000 |
# | pctrental2k | Numeric | Scale | Percent Rentals in 2000 |
# | pctmarried2k | Numeric | Scale | Percent of population 15 years and older, married, 2000 |
# | pctchild2k | Numeric | Scale | Percentage of households with children 0-17, 2000 |
# | racediversity2k | Numeric | Scale | Racial diversity index, 2000 |
# | medrent2k | Numeric | Scale | Median Gross Rent, 2000 |
# | medhhinc2k | Numeric | Scale | Median Household Income, 2000 |
# | meantrav2k | Numeric | Scale | Mean travel time to work in minutes, 2000 |
# | medlengthres2k | Numeric | Scale | Median length of residence in housing unit, 2000 |
# | pctsamehouse2k | Numeric | Scale | Percentage living in same house, from 1995 to 2000 |
# | pctfemale2k | Numeric | Scale | Percentage female, 2000 |
# | pctunemp2k | Numeric | Scale | Percentage of unemployed labor force, 2000 |
# | diversityfb2k | Numeric | Scale | Foreign born diversity index, 2000 |
# | pctpov2k | Numeric | Scale | Percentage population below poverty level, 2000 |
# | pctwalk2k | Numeric | Scale | Percent of people who walk in 2000 |
# | pctbike2k | Numeric | Scale | Percentage biked to work, 2000 |
# | pctdrove2k | Numeric | Scale | Percentage drove to work, 2000 |
# | density2000 | Numeric | Scale | Population density, 2000 |
# | housingdensity2000 | Numeric | Scale | Housing density, 2000 |

# %%
# Description of the Geolytics variables

df[geo].describe()
# Out:
#          MedAge2k     pctba2k  racediversity2k    medrent2k     medhhinc2k  \
# count  500.000000  500.000000       500.000000   500.000000     500.000000
# mean    36.841400   26.283277         0.317414   628.280000   46521.902000
# std      5.971253   15.153137         0.225454   220.919171   18932.564291
# min     20.100000    1.933315         0.015193     0.000000   11341.000000
# 25%     33.600000   15.035511         0.108525   473.750000   34155.750000
# 50%     36.550000   21.653875         0.272383   591.500000   42209.500000
# 75%     39.800000   35.395331         0.504054   723.000000   54067.000000
# max     73.800000   87.368421         0.818835  1900.000000  183686.000000
t.show()

# %% [markdown]
# # Models

# %% [markdown]
# Differently from the analysis on the paper, in this project, the research question is: why are arts where they are? What makes some places more attractive for the arts than others?
#
# 1. Linear regression model (I and II)
# 2. Cross validation
# 3. Decision trees
# 4. Random forest
# 5. Cluster Analysis
# 6. Autocorrelation
# 7. Time Series

# %% [markdown]
# ## Linear Regression Model I

# %% [markdown]
# I start here with the linear regression model, since it is the simplest method to fitting the data. This was also used in my previous paper. The equation of this regression is:
#
# <center> $ Arts_{2014} = \alpha + \beta * Arts_{1998} + \gamma * Jobs_{1998} + Control Variables + \epsilon $ </center>
#
# I first start with only education as a control variable.

# %%
# Defining a linear model function. 

def linear_model_function(X, y):
    
    # Loading the package
    from sklearn import linear_model, metrics

    # Adding the intercept 
    X = sm.add_constant(X)
        
    # Fit the linear model
    model = linear_model.LinearRegression()
    results = model.fit(X, y)
    model = sm.OLS(y, X)
    results = model.fit()

    # Pring result
    print(results.summary())

# %%
X = df[["JobsN_1998", "ArtsN_1998", "CollProfLv90"]]
y = df["ArtsN_2014"]

linear_model_function(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     283.9
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):          3.02e-107
# Time:                        19:50:59   Log-Likelihood:                -3417.9
# No. Observations:                 500   AIC:                             6844.
# Df Residuals:                     496   BIC:                             6861.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const            4.7036     20.877      0.225      0.822       -36.315    45.722
# JobsN_1998       0.0043      0.001      3.310      0.001         0.002     0.007
# ArtsN_1998       0.9952      0.050     19.834      0.000         0.897     1.094
# CollProfLv90     8.1717     79.667      0.103      0.918      -148.355   164.698
# ==============================================================================
# Omnibus:                      439.483   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           109420.720
# Skew:                           2.913   Prob(JB):                         0.00
# Kurtosis:                      75.238   Cond. No.                     1.08e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn import feature_selection, linear_model

def get_linear_model_metrics(X, y, algo):
    # get the pvalue of X given y. Ignore f-stat for now.
    pvals = feature_selection.f_regression(X, y)[1]
    # start with an empty linear regression object
    # .fit() runs the linear regression function on X and y
    algo.fit(X,y)
    residuals = (y-algo.predict(X)).values

    # print the necessary values
    print 'P Values:', pvals
    print 'Coefficients:', algo.coef_
    print 'y-intercept:', algo.intercept_
    print 'R-Squared:', algo.score(X,y)
    
    print 'Residuals Histogram : '
    plt.figure() 
    plt.hist(residuals, bins=np.ceil(np.sqrt(len(y))))
    
    # keep the model
    return algo

# %%
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
# P Values: [  6.35825881e-239   2.02267514e-055   8.80415000e-011   2.78001983e-004
#    4.03272467e-016]
# Coefficients: [  9.28109922e-01   1.69680383e+00  -7.58479205e+03  -8.09407181e+03
#   -4.26709597e+04]
# y-intercept: 174259.480082
# R-Squared: 0.894360774423
# Residuals Histogram :
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# We see that all three independent variables are significant, so we can assume that education, non-arts jobs, and the arts had an impact in the growth of arts; with education having the highest impact of all three. This shows that on average education is important for the development of the arts, however, what else is?

# %% [markdown]
# ### Cross Validation

# %%
def cross_val_function(data, X, y):
    
    # Loading the package
    from sklearn import cross_validation

    # Defining the cross validation object
    kf = cross_validation.KFold(len(df), n_folds=5, shuffle=True)

    # Creating empty lists
    mse_values = []
    scores = []
    n = 0
    
    # Running the cross-validation
    print "~~~~ CROSS VALIDATION each fold ~~~~"
    for train_index, test_index in kf:
        lm = linear_model.LinearRegression().fit(X.iloc[train_index], y.iloc[train_index])
        mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(X.iloc[test_index])))
        scores.append(lm.score(X, y))
        n+=1
        print 'Model', n
        print 'MSE:', mse_values[n-1]
        print 'R2:', scores[n-1]


    print "~~~~ SUMMARY OF CROSS VALIDATION ~~~~"
    print 'Mean of MSE for all folds:', np.mean(mse_values)
    print 'Mean of R2 for all folds:', np.mean(scores)

# %%
cross_val_function(df, X, y)
# Out:
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 9535925.49723
# R2: 0.893700289894
# Model 2
# MSE: 9262940.42838
# R2: 0.893566709992
# Model 3
# MSE: 12361831.2644
# R2: 0.893912728959
# Model 4
# MSE: 21989288.4424
# R2: 0.893122733287
# Model 5
# MSE: 8479183.08646
# R2: 0.894104730351
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 12325833.7438
# Mean of R2 for all folds: 0.893681438497

# %% [markdown]
# The cross-validation R2 for all folds are close to the R2 from the original model, so we can assume the original model is good.

# %% [markdown]
# ## Linear Regression Model II

# %% [markdown]
# In this second part, all the core variables are added as independent variables, to see which variables caused an impact on the arts.

# %%
X = df[["JobsN_1998", "ArtsN_1998", "CollProfLv90", "CrimeRate1999county", "Democ92", "NonWhite_90"]]
y = df["ArtsN_2014"]

linear_model_function(X, y)
cross_val_function(df, X, y)
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     143.4
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):          9.76e-105
# Time:                        19:52:51   Log-Likelihood:                -3415.4
# No. Observations:                 500   AIC:                             6845.
# Df Residuals:                     493   BIC:                             6874.
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# const                   0.5214     47.988      0.011      0.991       -93.765    94.808
# JobsN_1998              0.0042      0.001      3.049      0.002         0.001     0.007
# ArtsN_1998              0.9996      0.050     19.892      0.000         0.901     1.098
# CollProfLv90           -4.2075     81.576     -0.052      0.959      -164.487   156.072
# CrimeRate1999county     0.0106      0.005      1.959      0.051     -3.15e-05     0.021
# Democ92                -0.7021      1.182     -0.594      0.553        -3.025     1.620
# NonWhite_90            -0.0022      0.002     -1.207      0.228        -0.006     0.001
# ==============================================================================
# Omnibus:                      431.636   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           101041.405
# Skew:                           2.837   Prob(JB):                         0.00
# Kurtosis:                      72.410   Cond. No.                     1.18e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 44367.852288
# R2: 0.62942524948
# Model 2
# MSE: 14455.1431006
# R2: 0.633901729194
# Model 3
# MSE: 91181.0223723
# R2: 0.604944222918
# Model 4
# MSE: 53112.8498951
# R2: 0.634688338763
# Model 5
# MSE: 162660.658823
# R2: 0.576920377802
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 73155.5052958
# Mean of R2 for all folds: 0.615975983632
# P Values: [  3.45417322e-045   8.33472643e-108   3.86712299e-006   6.33455829e-005
#    1.06114776e-002   2.32662767e-002]
# Coefficients: [  4.18090581e-03   9.99580478e-01  -4.20751002e+00   1.06148227e-02
#   -7.02084582e-01  -2.24772976e-03]
# y-intercept: 0.521385941588
# R-Squared: 0.635721919757
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# We see that again only education is significant on the impact of the arts, while the other variables show a p-value of over .05.
#
# If we remove rent, percent white, and crime rate, we have that percent democrats also have an impact on the arts.

# %%
# Defining variables
X = df[["JobsN_1998", "ArtsN_1998", "CollProfLv90", "Democ92"]]
y = df["ArtsN_2014"]

linear_model_function(X, y)
cross_val_function(df, X, y)
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     212.7
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):          4.97e-106
# Time:                        19:52:59   Log-Likelihood:                -3417.8
# No. Observations:                 500   AIC:                             6846.
# Df Residuals:                     495   BIC:                             6867.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const           24.1948     46.715      0.518      0.605       -67.590   115.979
# JobsN_1998       0.0044      0.001      3.330      0.001         0.002     0.007
# ArtsN_1998       0.9967      0.050     19.810      0.000         0.898     1.096
# CollProfLv90    11.4630     80.042      0.143      0.886      -145.800   168.726
# Democ92         -0.5047      1.082     -0.466      0.641        -2.630     1.621
# ==============================================================================
# Omnibus:                      441.282   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           109199.380
# Skew:                           2.937   Prob(JB):                         0.00
# Kurtosis:                      75.160   Cond. No.                     1.08e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 110723.681923
# R2: 0.594727124472
# Model 2
# MSE: 23315.2265095
# R2: 0.631742835403
# Model 3
# MSE: 35620.2242577
# R2: 0.630793005148
# Model 4
# MSE: 191542.097062
# R2: 0.550099240823
# Model 5
# MSE: 19936.1830924
# R2: 0.631512474606
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 76227.482569
# Mean of R2 for all folds: 0.60777493609
# P Values: [  3.45417322e-045   8.33472643e-108   3.86712299e-006   1.06114776e-002]
# Coefficients: [  4.37457763e-03   9.96654357e-01   1.14630321e+01  -5.04716687e-01]
# y-intercept: 24.1948177665
# R-Squared: 0.632164272918
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Now all the variables are significant at 95%. The cross-validation shows that the R2 is lower than the original linear model, and closer to the first linear regression model, so I would have my doubts on keeping the Democ92 variable.

# %% [markdown]
# ## Models with Scenes Dimensions

# %% [markdown]
# Here I add the scenes dimensions variables.

# %%
#Dependent variable is arts: how did jobs and the other variables influence the growth of arts?

X = df[['JobsN_1998', 'ArtsN_1998', 'Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 
        'Neighborly', 'Formality','Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 
        'Corporateness', 'Ethnicity']]
y = df['JobsN_2014']

linear_model_function(X, y)
cross_val_function(df, X, y)
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             JobsN_2014   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     244.5
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):          2.73e-224
# Time:                        19:53:19   Log-Likelihood:                -4773.4
# No. Observations:                 500   AIC:                             9583.
# Df Residuals:                     482   BIC:                             9659.
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const             1.287e+05      1e+05      1.281      0.201     -6.86e+04  3.26e+05
# JobsN_1998           0.9283      0.023     40.791      0.000         0.884     0.973
# ArtsN_1998           2.0459      0.799      2.561      0.011         0.476     3.615
# Traditionalistic  8142.4689   1.07e+04      0.761      0.447     -1.29e+04  2.92e+04
# Self_Expressive    264.5419   5405.062      0.049      0.961     -1.04e+04  1.09e+04
# Utilitarian       1798.4928   2860.245      0.629      0.530     -3821.596  7418.582
# Charismatic      -3404.8344   5987.245     -0.569      0.570     -1.52e+04  8359.490
# Egalitarian       4426.2825   6529.670      0.678      0.498     -8403.852  1.73e+04
# Neighborly       -1.078e+04   6937.839     -1.554      0.121     -2.44e+04  2850.196
# Formality        -3030.3599   2834.089     -1.069      0.285     -8599.056  2538.336
# Exhibitionism     5327.7369   4781.903      1.114      0.266     -4068.215  1.47e+04
# Glamorous         2871.5414   5930.757      0.484      0.628     -8781.791  1.45e+04
# Transgressive    -7221.7076   5487.428     -1.316      0.189      -1.8e+04  3560.528
# Rational          1551.1721   5496.401      0.282      0.778     -9248.694  1.24e+04
# Locality         -1497.3198   4120.755     -0.363      0.716     -9594.182  6599.542
# State_Scenes     -1370.0911   5614.278     -0.244      0.807     -1.24e+04  9661.391
# Corporateness     1368.6826   6076.195      0.225      0.822     -1.06e+04  1.33e+04
# Ethnicity        -4.166e+04   1.47e+04     -2.831      0.005     -7.06e+04 -1.27e+04
# ==============================================================================
# Omnibus:                      155.290   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              983.172
# Skew:                           1.194   Prob(JB):                    3.21e-214
# Kurtosis:                       9.441   Cond. No.                     8.83e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.83e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 10644420.5911
# R2: 0.894914420982
# Model 2
# MSE: 18314413.9531
# R2: 0.895183578857
# Model 3
# MSE: 8740661.49666
# R2: 0.895737111573
# Model 4
# MSE: 12627535.7554
# R2: 0.894667210338
# Model 5
# MSE: 11817624.2142
# R2: 0.894991730391
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 12428931.2021
# Mean of R2 for all folds: 0.895098810428
# P Values: [  6.35825881e-239   2.02267514e-055   1.54133866e-015   5.83795732e-001
#    8.81662981e-022   8.46749802e-002   4.90965901e-009   8.80415000e-011
#    1.43688133e-007   7.85862139e-004   4.65006476e-001   2.78001983e-004
#    1.01552307e-010   8.62123848e-022   5.68740095e-010   2.48704389e-022
#    4.03272467e-016]
# Coefficients: [  9.28262561e-01   2.04590568e+00   8.14246894e+03   2.64541922e+02
#    1.79849277e+03  -3.40483435e+03   4.42628246e+03  -1.07819499e+04
#   -3.03035986e+03   5.32773691e+03   2.87154145e+03  -7.22170760e+03
#    1.55117206e+03  -1.49731985e+03  -1.37009106e+03   1.36868261e+03
#   -4.16583085e+04]
# y-intercept: 128729.708451
# R-Squared: 0.8960878785
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Dependent variable is arts: how did jobs and the other variables influence the growth of arts?

X = df[["JobsN_1998", "ArtsN_1998", 'Traditionalistic','Self_Expressive', 'Charismatic', 'Glamorous']]
y = df["ArtsN_2014"]


linear_model_function(X, y)
cross_val_function(df, X, y)
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     156.3
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):          1.14e-110
# Time:                        19:53:53   Log-Likelihood:                -3401.5
# No. Observations:                 500   AIC:                             6817.
# Df Residuals:                     493   BIC:                             6846.
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const             -663.3102   1513.272     -0.438      0.661     -3636.568  2309.947
# JobsN_1998           0.0046      0.001      3.473      0.001         0.002     0.007
# ArtsN_1998           0.9385      0.049     19.151      0.000         0.842     1.035
# Traditionalistic  -887.4250    469.813     -1.889      0.059     -1810.507    35.657
# Self_Expressive    805.9452    193.109      4.174      0.000       426.527  1185.363
# Charismatic       1055.7748    265.780      3.972      0.000       533.573  1577.976
# Glamorous         -788.1530    249.390     -3.160      0.002     -1278.152  -298.154
# ==============================================================================
# Omnibus:                      387.795   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            71245.099
# Skew:                           2.404   Prob(JB):                         0.00
# Kurtosis:                      61.281   Cond. No.                     2.15e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 161031.550109
# R2: 0.594781929652
# Model 2
# MSE: 23565.9114595
# R2: 0.653176132411
# Model 3
# MSE: 170329.613728
# R2: 0.569412083068
# Model 4
# MSE: 10936.7141602
# R2: 0.654561362103
# Model 5
# MSE: 31529.4215877
# R2: 0.654572853769
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 79478.642209
# Mean of R2 for all folds: 0.625300872201
# P Values: [  3.45417322e-045   8.33472643e-108   1.78444406e-008   8.02252499e-005
#    1.82448544e-002   9.47471944e-001]
# Coefficients: [  4.61125844e-03   9.38474857e-01  -8.87425024e+02   8.05945234e+02
#    1.05577480e+03  -7.88153007e+02]
# y-intercept: -663.310160062
# R-Squared: 0.655450062605
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Dependent variable is arts: how did jobs and the other variables influence the growth of arts?

X = df[["JobsN_1998",'Self_Expressive', 'Charismatic', 'Glamorous']]
y = df["arts_change"]


linear_model_function(X, y)
cross_val_function(df, X, y)
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            arts_change   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     11.91
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):           3.00e-09
# Time:                        19:54:04   Log-Likelihood:                -3403.9
# No. Observations:                 500   AIC:                             6818.
# Df Residuals:                     495   BIC:                             6839.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# const           -2853.0269    859.135     -3.321      0.001     -4541.027 -1165.027
# JobsN_1998          0.0043      0.001      4.384      0.000         0.002     0.006
# Self_Expressive   843.6165    188.212      4.482      0.000       473.824  1213.409
# Charismatic       781.9470    231.836      3.373      0.001       326.443  1237.451
# Glamorous        -714.9032    247.782     -2.885      0.004     -1201.738  -228.068
# ==============================================================================
# Omnibus:                      324.242   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            65323.155
# Skew:                           1.706   Prob(JB):                         0.00
# Kurtosis:                      58.892   Cond. No.                     1.20e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 34595.7794669
# R2: 0.0859225601067
# Model 2
# MSE: 25245.9876337
# R2: 0.0858180682896
# Model 3
# MSE: 57949.5570395
# R2: 0.0823611460017
# Model 4
# MSE: 20686.0314259
# R2: 0.0860065824679
# Model 5
# MSE: 114452.679619
# R2: 0.070080827919
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 50586.007037
# Mean of R2 for all folds: 0.082037836957
# P Values: [  2.52743365e-05   4.05236128e-04   1.47216169e-02   9.51389113e-01]
# Coefficients: [  4.31380679e-03   8.43616508e+02   7.81947031e+02  -7.14903228e+02]
# y-intercept: -2853.02690469
# R-Squared: 0.0878219555339
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Dependent variable is arts: how did jobs and the other variables influence the growth of arts?

X = df[['JobsN_1998', 'ArtsN_1998', 'Neighborly', 'Transgressive', 'Ethnicity']]
y = df['JobsN_2014']


linear_model_function(X, y)
cross_val_function(df, X, y)
get_linear_model_metrics(X, y, linear_model.LinearRegression())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             JobsN_2014   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     836.5
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):          1.91e-238
# Time:                        19:54:20   Log-Likelihood:                -4777.5
# No. Observations:                 500   AIC:                             9567.
# Df Residuals:                     494   BIC:                             9592.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# const          1.743e+05   3.48e+04      5.005      0.000      1.06e+05  2.43e+05
# JobsN_1998        0.9281      0.021     44.094      0.000         0.887     0.969
# ArtsN_1998        1.6968      0.756      2.245      0.025         0.212     3.182
# Neighborly    -7584.7921   2641.038     -2.872      0.004     -1.28e+04 -2395.739
# Transgressive -8094.0718   3187.346     -2.539      0.011     -1.44e+04 -1831.646
# Ethnicity     -4.267e+04   9787.148     -4.360      0.000     -6.19e+04 -2.34e+04
# ==============================================================================
# Omnibus:                      161.457   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1045.823
# Skew:                           1.243   Prob(JB):                    7.99e-228
# Kurtosis:                       9.635   Cond. No.                     3.15e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.15e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 8195369.43665
# R2: 0.893024093925
# Model 2
# MSE: 13685710.1964
# R2: 0.893622474504
# Model 3
# MSE: 9526500.93134
# R2: 0.893712330303
# Model 4
# MSE: 16202436.4604
# R2: 0.893467095441
# Model 5
# MSE: 14881367.4904
# R2: 0.893426254156
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 12498276.903
# Mean of R2 for all folds: 0.893450449666
# P Values: [  6.35825881e-239   2.02267514e-055   8.80415000e-011   2.78001983e-004
#    4.03272467e-016]
# Coefficients: [  9.28109922e-01   1.69680383e+00  -7.58479205e+03  -8.09407181e+03
#   -4.26709597e+04]
# y-intercept: 174259.480082
# R-Squared: 0.894360774423
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# And we see here that even though the R2 is high, most of the variables are not significant. So I run decision trees and random forests in order to see which variables are more important for the arts.

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### The Scenes variables

# %% [markdown]
# Here we look for the feature importances of the scenes variables for changes in the arts. So what traits helped for and increase or decrease in the number of arts jobs in a zip code?

# %%
# The decision tree function 

def decision_tree(X, y):
    
    from sklearn.model_selection import cross_val_score
    from sklearn.tree import DecisionTreeClassifier

    # Creating the decision tree object 
    dt = DecisionTreeClassifier(criterion='entropy', random_state=4)
    
    # Fitting the variables 
    dt.fit(X, y)

    # Put the feature importances in a list
    feature_importances_array = dt.feature_importances_

    # Put the features themselves in a list
    features_array = X.columns.values 

    # Turn these into a Data Frame
    feature_importances_df = pd.DataFrame({'importances' : feature_importances_array,
                                           'features' : features_array})

    # Sort the feature importances highest to lowest
    return feature_importances_df.sort(columns='importances',ascending=False)

# %%
#Cross validation function for decision tree

def dt_cross_val(X, y):
    from sklearn.model_selection import cross_val_score

    # Get the cross validated accuracy score for each of three cross validation folds
    dt = DecisionTreeClassifier(criterion='entropy', random_state=4)
    dt_scores = cross_val_score(dt, X, y)

    # Take the mean of these scores
    print round(dt_scores.mean(), 5)

# %%
decision_tree(df[scenes], df['arts_change'])
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 11          Locality     0.229725
# 10          Rational     0.096748
# 7      Exhibitionism     0.094152
# 2        Utilitarian     0.091783
# 8          Glamorous     0.073956
# 9      Transgressive     0.053659
# 13     Corporateness     0.051462
# 3        Charismatic     0.047600
# 1    Self_Expressive     0.045399
# 4        Egalitarian     0.045214
# 0   Traditionalistic     0.042839
# 14         Ethnicity     0.041422
# 6          Formality     0.030972
# 12      State_Scenes     0.030816
# 5         Neighborly     0.024252

# %%
dt_cross_val(df[scenes], df['arts_change'])
# Out:
# 0.0186

# %%
decision_tree(df[scenes], df['ArtsN_2014'])
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 1    Self_Expressive     0.132110
# 11          Locality     0.130703
# 9      Transgressive     0.091930
# 0   Traditionalistic     0.090799
# 12      State_Scenes     0.080662
# 2        Utilitarian     0.072800
# 14         Ethnicity     0.056801
# 8          Glamorous     0.050695
# 4        Egalitarian     0.050294
# 10          Rational     0.049886
# 7      Exhibitionism     0.043454
# 13     Corporateness     0.043035
# 6          Formality     0.038019
# 5         Neighborly     0.035137
# 3        Charismatic     0.033676

# %%
dt_cross_val(df[scenes], df['ArtsN_2014'])
# Out:
# 0.01026

# %% [markdown]
# We see that exhibitionism is the most important zip code trait for both arts in 2014 and arts change. But for more changes to occur, the other traits are formality, locality, utilitarian. While the arts in 2014 are more influenced by egalitarian, locality, neighborly, corporateness traits.
#
#
# The cross validation score is very low, but it might be due to the diversity of the variables included in the analysis; that might be contradicting among each other.
#
# If we consider only the variables where there was increase in the arts, then we see that self-expressive, utilitarian, corporateness, ethnicity, and locality became more important for the arts.

# %%
# If we consider the arts changes that were positive and negative, the results might differ. 

# Defining the positive arts variables
positive_arts = df[df.arts_change > 0]

# Defining the negative arts variables
negative_arts = df[df.arts_change <= 0]

# %%
X = positive_arts[scenes]
y = positive_arts['arts_change']

dt_cross_val(X, y)
decision_tree(X, y)
# Out:
# 0.00765
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 1    Self_Expressive     0.159429
# 5         Neighborly     0.118941
# 3        Charismatic     0.109879
# 8          Glamorous     0.104736
# 14         Ethnicity     0.099229
# 11          Locality     0.071825
# 12      State_Scenes     0.062152
# 6          Formality     0.051605
# 10          Rational     0.039695
# 13     Corporateness     0.035152
# 7      Exhibitionism     0.034884
# 9      Transgressive     0.031073
# 2        Utilitarian     0.030275
# 0   Traditionalistic     0.028955
# 4        Egalitarian     0.022170

# %% [markdown]
# And if we compare to the zipcodes where the arts had a decrease, we see that ethnicity, transgressive, utilitarian, locality, and formality were the important traits.

# %%
X = negative_arts[scenes]
y = negative_arts['arts_change']

dt_cross_val(X, y)
decision_tree(X, y)
# Out:
# 0.00933
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 11          Locality     0.239551
# 6          Formality     0.104335
# 0   Traditionalistic     0.103110
# 10          Rational     0.094254
# 14         Ethnicity     0.063802
# 7      Exhibitionism     0.054612
# 3        Charismatic     0.054032
# 13     Corporateness     0.050690
# 1    Self_Expressive     0.049045
# 8          Glamorous     0.045937
# 12      State_Scenes     0.043956
# 2        Utilitarian     0.035735
# 9      Transgressive     0.030840
# 5         Neighborly     0.016243
# 4        Egalitarian     0.013857

# %% [markdown]
# In conclusion, we can say that the ethnicity, locality or utilitan wouldn't steer the arts in one way or another (because they are present on the top of the feature importances of both positive and negative arts), but that self-expression and corporateness is favorable for the arts, while transgressive and formality are unfavorable for the arts.

# %% [markdown]
# #### Visualizing decision tree
#
# The code to visualize the decision tree is below. However, we need a software called graphviz, and the decision tree is so large that it is impractical to paste it here.

# %%
# from sklearn.tree import export_graphviz

# export_graphviz(dt, out_file='tree5.dot')

# %% [markdown]
# ### Geolytics and core variables

# %% [markdown]
# On this analysis, we add the other control variables: the socio-economic variables, and habits. Conducting the same analysis as before.

# %%
X = df[geo_core]
y = df['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 20              Pop2000     0.173324
# 1               pctba2k     0.096681
# 10           pctchild2k     0.073503
# 22              Democ92     0.059583
# 9          pctmarried2k     0.057653
# 21  CrimeRate1999county     0.054816
# 3             medrent2k     0.046709
# 18          density2000     0.042997
# 17            pctwalk2k     0.038234
# 11           pctunemp2k     0.034111
# 7        pctsamehouse2k     0.032663
# 6        medlengthres2k     0.030501
# 5            meantrav2k     0.027782
# 8           pctfemale2k     0.026951
# 2       racediversity2k     0.026229
# 13          pctrental2k     0.025594
# 15            pctbike2k     0.023375
# 12        diversityfb2k     0.023217
# 19   housingdensity2000     0.017739
# 16           pctdrove2k     0.017041
# 23          NonWhite_90     0.016065
# 24         CollProfLv90     0.015855
# 14             pctpov2k     0.013737
# 4            medhhinc2k     0.012923
# 0              MedAge2k     0.012715

# %%
dt_cross_val(X, y)
# Out:
# 0.01592

# %% [markdown]
# Here we see that the most important traits are for people to be living in the same house for the last 5 years, the median income, population diversity and density. Again, the cross validation score is practically zero.

# %% [markdown]
# And now dividing the data into the positive and negative arts changes, we have that walkability, stability of households, and presence of children are favorable for the arts; while percent non white, percent rental, and median age helped for decreases in the arts.

# %%
X = positive_arts[geo_core]
y = positive_arts['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 20              Pop2000     0.175438
# 4            medhhinc2k     0.100839
# 10           pctchild2k     0.084574
# 19   housingdensity2000     0.069931
# 17            pctwalk2k     0.056258
# 16           pctdrove2k     0.053902
# 15            pctbike2k     0.034745
# 13          pctrental2k     0.033866
# 5            meantrav2k     0.031318
# 1               pctba2k     0.029241
# 23          NonWhite_90     0.027905
# 2       racediversity2k     0.027135
# 7        pctsamehouse2k     0.027031
# 0              MedAge2k     0.025991
# 18          density2000     0.025952
# 21  CrimeRate1999county     0.025126
# 24         CollProfLv90     0.024889
# 22              Democ92     0.024744
# 11           pctunemp2k     0.024664
# 9          pctmarried2k     0.023312
# 3             medrent2k     0.021235
# 8           pctfemale2k     0.018757
# 12        diversityfb2k     0.017181
# 14             pctpov2k     0.014673
# 6        medlengthres2k     0.001293

# %%
dt_cross_val(X, y)
# Out:
# 0.01847

# %%
X = negative_arts[geo_core]
y = negative_arts['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 20              Pop2000     0.148447
# 24         CollProfLv90     0.086081
# 19   housingdensity2000     0.077968
# 12        diversityfb2k     0.059416
# 14             pctpov2k     0.057031
# 2       racediversity2k     0.056702
# 7        pctsamehouse2k     0.053213
# 13          pctrental2k     0.048013
# 23          NonWhite_90     0.045415
# 9          pctmarried2k     0.042651
# 11           pctunemp2k     0.042209
# 21  CrimeRate1999county     0.034901
# 5            meantrav2k     0.030100
# 10           pctchild2k     0.028458
# 0              MedAge2k     0.028185
# 16           pctdrove2k     0.027555
# 18          density2000     0.025644
# 4            medhhinc2k     0.022713
# 3             medrent2k     0.020590
# 6        medlengthres2k     0.016863
# 22              Democ92     0.014813
# 1               pctba2k     0.010284
# 17            pctwalk2k     0.009314
# 15            pctbike2k     0.006929
# 8           pctfemale2k     0.006504

# %%
dt_cross_val(X, y)
# Out:
# 0.05562

# %% [markdown]
# ### Arts and jobs variables
#
# Here we look at which years or variables were more important to attracting the arts. Is arts what attract the arts, or do jobs help too? In this case, I use the Arts in 2014 as dependent variable, as it is the outcome, instead of the arts change.

# %%
X = df[arts_jobs]
y = df['ArtsN_2014']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#       features  importances
# 30  ArtsN_2013     0.377378
# 28  ArtsN_2012     0.138207
# 1   JobsN_1998     0.035996
# 19  JobsN_2007     0.029375
# 0   ArtsN_1998     0.026473
# 4   ArtsN_2000     0.025561
# 8   ArtsN_2002     0.025135
# 16  ArtsN_2006     0.024182
# 12  ArtsN_2004     0.023682
# 3   JobsN_1999     0.022915
# 18  ArtsN_2007     0.022460
# 26  ArtsN_2011     0.022109
# 6   ArtsN_2001     0.021797
# 11  JobsN_2003     0.015565
# 17  JobsN_2006     0.014001
# 22  ArtsN_2009     0.013973
# 14  ArtsN_2005     0.013489
# 10  ArtsN_2003     0.013238
# 20  ArtsN_2008     0.012871
# 2   ArtsN_1999     0.012792
# 31  JobsN_2013     0.012195
# 15  JobsN_2005     0.011594
# 23  JobsN_2009     0.011465
# 25  JobsN_2010     0.011123
# 24  ArtsN_2010     0.010626
# 21  JobsN_2008     0.008734
# 9   JobsN_2002     0.008571
# 7   JobsN_2001     0.008333
# 5   JobsN_2000     0.007047
# 29  JobsN_2012     0.006850
# 27  JobsN_2011     0.006732
# 13  JobsN_2004     0.005534

# %% [markdown]
# Of course arts in 2013 would be of the highest impact for arts in 2014, however, it is surprising to see that arts in 2005, 2010, and 2007 are so much closer to the top, as well as jobs in 2001 and 1999.

# %% [markdown]
# ## Random Forest

# %% [markdown]
# Instead of just a decision tree, we now try the random forest algorithm.

# %%
# Random forest function

def random_forest(X, y): 

    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import cross_val_score
    
    rf = RandomForestClassifier(n_estimators = 1000, class_weight='balanced')
    
    # Get the cross validated accuracy score for each of three cross validation folds (one line below):
    rf_scores = cross_val_score(rf, X, y)

    # Add one line to simply print out the resulting scores:
    print str(rf_scores)

    # Get the mean of these scores (one line below):
    print "mean of cross validation scores: " + str(round(rf_scores.mean(), 3))

    rf.fit(X, y)
    fi = rf.feature_importances_
    feat = X.columns.values
    feat_df = pd.DataFrame({"importances": fi,
                            "features": feat})
    return feat_df.sort("importances", ascending=False)

# %%
X = df[scenes]
y = df['arts_change']

random_forest(X, y)
# Out:
# [ 0.01333333  0.01492537  0.        ]
# mean of cross validation scores: 0.009
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 11          Locality     0.074148
# 10          Rational     0.073609
# 6          Formality     0.071305
# 14         Ethnicity     0.069200
# 8          Glamorous     0.068902
# 2        Utilitarian     0.066796
# 7      Exhibitionism     0.066417
# 0   Traditionalistic     0.066412
# 13     Corporateness     0.064455
# 3        Charismatic     0.064375
# 4        Egalitarian     0.064028
# 9      Transgressive     0.063314
# 12      State_Scenes     0.063299
# 5         Neighborly     0.062336
# 1    Self_Expressive     0.061404

# %%
X = positive_arts[scenes]
y = positive_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.01075269  0.01219512  0.        ]
# mean of cross validation scores: 0.008
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 10          Rational     0.075532
# 2        Utilitarian     0.071122
# 11          Locality     0.071023
# 6          Formality     0.069198
# 14         Ethnicity     0.068222
# 0   Traditionalistic     0.067316
# 8          Glamorous     0.067056
# 7      Exhibitionism     0.065802
# 3        Charismatic     0.065389
# 1    Self_Expressive     0.064768
# 13     Corporateness     0.063624
# 5         Neighborly     0.063034
# 12      State_Scenes     0.062935
# 4        Egalitarian     0.062771
# 9      Transgressive     0.062208

# %%
X = negative_arts[scenes]
y = negative_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.03508772  0.05769231  0.11111111]
# mean of cross validation scores: 0.068
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 10          Rational     0.076401
# 11          Locality     0.075353
# 8          Glamorous     0.073552
# 6          Formality     0.070580
# 14         Ethnicity     0.069084
# 0   Traditionalistic     0.068372
# 13     Corporateness     0.067706
# 7      Exhibitionism     0.067022
# 2        Utilitarian     0.064742
# 3        Charismatic     0.063719
# 9      Transgressive     0.063362
# 4        Egalitarian     0.062760
# 12      State_Scenes     0.060681
# 5         Neighborly     0.059055
# 1    Self_Expressive     0.057612

# %% [markdown]
# ### For the other variables

# %%
X = df[geo_core]
y = df['arts_change']

random_forest(X, y)
# Out:
# [ 0.01328904  0.032       0.12162162]
# mean of cross validation scores: 0.056
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 20              Pop2000     0.049537
# 12        diversityfb2k     0.048270
# 5            meantrav2k     0.047483
# 7        pctsamehouse2k     0.045266
# 9          pctmarried2k     0.042881
# 2       racediversity2k     0.042716
# 10           pctchild2k     0.042167
# 4            medhhinc2k     0.042135
# 24         CollProfLv90     0.041781
# 23          NonWhite_90     0.041453
# 13          pctrental2k     0.041423
# 14             pctpov2k     0.041301
# 22              Democ92     0.041129
# 16           pctdrove2k     0.040794
# 1               pctba2k     0.040075
# 3             medrent2k     0.038578
# 0              MedAge2k     0.038211
# 8           pctfemale2k     0.037609
# 15            pctbike2k     0.037267
# 17            pctwalk2k     0.037083
# 21  CrimeRate1999county     0.036903
# 11           pctunemp2k     0.035570
# 19   housingdensity2000     0.033256
# 18          density2000     0.032641
# 6        medlengthres2k     0.024470

# %%
X = positive_arts[geo_core]
y = positive_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.02197802  0.          0.05263158]
# mean of cross validation scores: 0.025
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 5            meantrav2k     0.054100
# 20              Pop2000     0.046630
# 10           pctchild2k     0.044300
# 7        pctsamehouse2k     0.044080
# 9          pctmarried2k     0.043835
# 14             pctpov2k     0.042868
# 12        diversityfb2k     0.042293
# 24         CollProfLv90     0.042181
# 4            medhhinc2k     0.042157
# 22              Democ92     0.042040
# 13          pctrental2k     0.040925
# 2       racediversity2k     0.040334
# 16           pctdrove2k     0.040171
# 23          NonWhite_90     0.040039
# 1               pctba2k     0.039803
# 17            pctwalk2k     0.039008
# 3             medrent2k     0.038965
# 8           pctfemale2k     0.038322
# 21  CrimeRate1999county     0.038262
# 0              MedAge2k     0.038198
# 11           pctunemp2k     0.036578
# 15            pctbike2k     0.035242
# 19   housingdensity2000     0.033093
# 18          density2000     0.031931
# 6        medlengthres2k     0.024646

# %%
X = negative_arts[geo_core]
y = negative_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.03361345  0.09259259  0.22222222]
# mean of cross validation scores: 0.116
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 12        diversityfb2k     0.053297
# 7        pctsamehouse2k     0.052271
# 20              Pop2000     0.052030
# 13          pctrental2k     0.044212
# 16           pctdrove2k     0.044020
# 2       racediversity2k     0.043950
# 0              MedAge2k     0.043837
# 9          pctmarried2k     0.042204
# 5            meantrav2k     0.041405
# 10           pctchild2k     0.040736
# 23          NonWhite_90     0.040480
# 1               pctba2k     0.040183
# 8           pctfemale2k     0.039186
# 24         CollProfLv90     0.038790
# 15            pctbike2k     0.038717
# 22              Democ92     0.038540
# 4            medhhinc2k     0.037396
# 14             pctpov2k     0.036080
# 11           pctunemp2k     0.035441
# 21  CrimeRate1999county     0.034843
# 3             medrent2k     0.034091
# 18          density2000     0.033950
# 19   housingdensity2000     0.033728
# 17            pctwalk2k     0.033385
# 6        medlengthres2k     0.027230

# %% [markdown]
# ### For the years before 2014

# %%
# Analysis for how the years preceeding affected 2014. 

X = df[arts_jobs]
y = df['ArtsN_2014']

random_forest(X, y)
# Out:
# [ 0.05102041  0.08661417  0.21518987]
# mean of cross validation scores: 0.118
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#       features  importances
# 30  ArtsN_2013     0.045722
# 28  ArtsN_2012     0.041678
# 26  ArtsN_2011     0.038313
# 24  ArtsN_2010     0.036244
# 8   ArtsN_2002     0.036189
# 18  ArtsN_2007     0.036027
# 16  ArtsN_2006     0.035227
# 20  ArtsN_2008     0.035085
# 22  ArtsN_2009     0.034687
# 0   ArtsN_1998     0.033989
# 4   ArtsN_2000     0.033939
# 2   ArtsN_1999     0.033541
# 12  ArtsN_2004     0.033298
# 14  ArtsN_2005     0.033077
# 10  ArtsN_2003     0.033010
# 6   ArtsN_2001     0.032429
# 29  JobsN_2012     0.029200
# 1   JobsN_1998     0.028806
# 31  JobsN_2013     0.028729
# 3   JobsN_1999     0.028010
# 9   JobsN_2002     0.027929
# 27  JobsN_2011     0.027363
# 25  JobsN_2010     0.026491
# 5   JobsN_2000     0.026454
# 7   JobsN_2001     0.026413
# 23  JobsN_2009     0.025806
# 21  JobsN_2008     0.025780
# 19  JobsN_2007     0.025549
# 11  JobsN_2003     0.025505
# 15  JobsN_2005     0.025367
# 17  JobsN_2006     0.025346
# 13  JobsN_2004     0.024798

# %% [markdown]
# ### For all the variables together
#
# In this analysis, we try all the variables together, against arts in 2014.
#
# As we can see from the feature importances, Arts in 2013 is the highest, followed by presence of children, mean travel time, arts in 2012, race diversity, and rent twice. This shows that previous presence of arts, as well as diversity of race and age are important factors for the arts in 2014. However, the scores are much lower than in the other analyses.

# %%
# Analysis with all the variables together, except 2014. 

X = df[all_var]
y = df['ArtsN_2014']

random_forest(X, y)
# Out:
# [ 0.05442177  0.07874016  0.11392405]
# mean of cross validation scores: 0.082
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 70           ArtsN_2013     0.022264
# 25           meantrav2k     0.020079
# 68           ArtsN_2012     0.019705
# 30           pctchild2k     0.019512
# 36           pctdrove2k     0.019164
# 22      racediversity2k     0.018775
# 34             pctpov2k     0.018711
# 33          pctrental2k     0.018484
# 1   CrimeRate1999county     0.018158
# 29         pctmarried2k     0.017858
# 27       pctsamehouse2k     0.017855
# 28          pctfemale2k     0.017640
# 37            pctwalk2k     0.017586
# 32        diversityfb2k     0.017545
# 31           pctunemp2k     0.016895
# 20             MedAge2k     0.016886
# 66           ArtsN_2011     0.016831
# 23            medrent2k     0.016504
# 24           medhhinc2k     0.016295
# 0               Pop2000     0.016121
# 48           ArtsN_2002     0.016121
# 21              pctba2k     0.015995
# 64           ArtsN_2010     0.015853
# 4          CollProfLv90     0.015773
# 38          density2000     0.015704
# 58           ArtsN_2007     0.015686
# 56           ArtsN_2006     0.015480
# 2               Democ92     0.015388
# 40           ArtsN_1998     0.015061
# 62           ArtsN_2009     0.014992
# ..                  ...          ...
# 49           JobsN_2002     0.012207
# 43           JobsN_1999     0.011896
# 26       medlengthres2k     0.011840
# 71           JobsN_2013     0.011761
# 67           JobsN_2011     0.011651
# 65           JobsN_2010     0.011309
# 57           JobsN_2006     0.011173
# 45           JobsN_2000     0.011078
# 47           JobsN_2001     0.011071
# 63           JobsN_2009     0.010884
# 51           JobsN_2003     0.010752
# 61           JobsN_2008     0.010740
# 59           JobsN_2007     0.010633
# 7           Utilitarian     0.010305
# 16             Locality     0.010261
# 53           JobsN_2004     0.010211
# 18        Corporateness     0.009904
# 55           JobsN_2005     0.009837
# 12        Exhibitionism     0.009834
# 11            Formality     0.009668
# 13            Glamorous     0.009638
# 14        Transgressive     0.009625
# 6       Self_Expressive     0.009614
# 8           Charismatic     0.009474
# 19            Ethnicity     0.009474
# 17         State_Scenes     0.009394
# 15             Rational     0.009320
# 9           Egalitarian     0.009163
# 5      Traditionalistic     0.009121
# 10           Neighborly     0.008766
#
# [72 rows x 2 columns]

# %% [markdown]
# ## Clustering Analysis

# %%
def set_colors(labels, colors='rgbykcm'):
    colored_labels = []
    for label in labels:
        colored_labels.append(colors[label])
    return colored_labels

# %%
plt.scatter(df['Utilitarian'], df['ArtsN_2014'])
plt.show()

# %%
# Fit a k-means estimator
estimator = KMeans(n_clusters=3)
X = df[["Exhibitionism", "ArtsN_2014"]]
estimator.fit(X)
# Clusters are given in the labels_ attribute
labels = estimator.labels_
# Plot the data
colors = set_colors(labels)
plt.scatter(df["Exhibitionism"], df["ArtsN_2014"], c=colors)
plt.xlabel("Exhibitionism")
plt.ylabel("ArtsN_2014")
plt.show()

# %% [markdown]
# We see a division into three distinct groups, but by size of the zip code, and one thin outlier group on the top.

# %% [markdown]
# ## DBSCAN Clustering

# %%
df = pd.read_csv("nomiss_sample.csv")

# sns.clustermap(df[["JobsN_2014", "ArtsN_2014"]], method="complete")

# %%
estimator = KMeans(n_clusters=4)

X = df[all_var]

estimator.fit(X)

# Clusters are given in the labels_ attribute
labels = estimator.labels_

colors = set_colors(labels)
plt.scatter(df['Exhibitionism'], df['ArtsN_2014'], c=colors)
plt.xlabel("Exhibitionism")
plt.ylabel("ArtsN_2014")
plt.show()

# %% [markdown]
# In this cluster, the colors are mixed together, because all the variables are considered in the analysis.

# %%
estimator = KMeans(n_clusters=3)
X = df[['Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 'Neighborly', 'Formality',
        'Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 
'Corporateness', 'Ethnicity', 'zip']]
estimator.fit(X)
# Clusters are given in the labels_ attribute
labels = estimator.labels_

colors = set_colors(labels)
plt.scatter(df['zip'], df['ArtsN_2014'], c=colors)
plt.xlabel("zip")
plt.ylabel("ArtsN_2014")
plt.show()

# %% [markdown]
# In this last clustering, we see that the colors are divided by zip code number, into an East, Central, and West division of the country.
#
# As we can see from both plots, cluster analyses are not very helpful on defining patterns in the data. The dots get mixed into each other; and only the zip code is able to set them apart in different groups.

# %% [markdown]
# ## Autocorrelation

# %%
# Loading the data file in the LONG format. (Created in R)
df_long = pd.read_csv("nomisslong_sample.csv")

# %%
# How does autocorrelation vary in different ranges of years? For arts.

period_lag = range(1, 15)
auto_corrs_list = []
for x in period_lag:
    y = df_long['ArtsN'].autocorr(lag=x)
    auto_corrs_list.append(y)
    print x, y
# Out:
# 1 -0.072502636837
# 2 -0.019333784748
# 3 -0.0178478604447
# 4 0.0309645387751
# 5 0.0216541111677
# 6 -0.00889121629323
# 7 -0.0186960378347
# 8 -0.0173698347505
# 9 0.024672532821
# 10 -0.0286070226386
# 11 0.0576784262754
# 12 -0.0554090035146
# 13 0.00399652061826
# 14 0.113967007957

# %%
plt.plot(period_lag, auto_corrs_list)

# %%
# Testing autocorrelation for the lag between all time periods. For jobs. 

period_lag = range(1, 15)
auto_corrs_list = []
for x in period_lag:
    y = df_long['JobsN'].autocorr(lag=x)
    auto_corrs_list.append(y)
    print x, y
# Out:
# 1 -0.0557095613078
# 2 -0.000309940872803
# 3 -0.034347826758
# 4 0.0749254779576
# 5 0.0873817495758
# 6 -0.0439491889978
# 7 0.00535665384213
# 8 -0.0621313993994
# 9 0.0848987354346
# 10 0.0114462365266
# 11 0.0527922117835
# 12 -0.0312721345734
# 13 -0.00816189407962
# 14 0.0561153772573

# %%
plt.plot(period_lag, auto_corrs_list)

# %% [markdown]
# One issue that was worrisome was autocorrelation between the years of analysis.
# By running the autocorrelation analysis with the different lags of years, we see that the autocorrelation is close to zero, confirming that the data is good to be run this way.

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Raschka, Sebastian. Python Machine Learning. Packt Publishing, 2015. <br/>
# Chapter 5. Compressing data via dimensionality reduction.

# %%
#Loading the datafile. This is just a sample of the data. N=500
df = pd.read_csv("nomiss_sample.csv")

# Dropping unnecessary variables (Some string variables too, like names of the zip code location)
df.drop(['pctba90', 'racediversity90', 'medrent90', 'medhhinc90', 'meantrav90', 'meanlengthres90', 'pctsamehouse90',
'pctfemale90', 'pctmarried90', 'pctchild90', 'pctunemp90', 'diversityanc90', 'pctrental90', 'pctpov90', 'pctbike90',
'pctdrove90', 'pctwalk90', 'density1990', 'housingdensity1990', 'Pop1990', 'Unnamed: 0','JobsT_1998', 'ArtsW_1998', 'JobsW_1998', 
'ArtSupport_1998', 'JobsT_1999', 'ArtsW_1999', 'JobsW_1999', 'ArtSupport_1999', 'JobsT_2000', 'ArtsW_2000', 'JobsW_2000',
 'ArtSupport_2000', 'JobsT_2001', 'ArtsW_2001', 'JobsW_2001', 'ArtSupport_2001', 'JobsT_2002', 'ArtsW_2002', 'JobsW_2002',
 'ArtSupport_2002', 'JobsT_2003', 'ArtsW_2003', 'JobsW_2003', 'ArtSupport_2003', 'JobsT_2004', 'ArtsW_2004', 'JobsW_2004',
 'ArtSupport_2004', 'JobsT_2005', 'ArtsW_2005', 'JobsW_2005', 'ArtSupport_2005', 'JobsT_2006', 'ArtsW_2006', 'JobsW_2006',
 'ArtSupport_2006', 'JobsT_2007', 'ArtsW_2007', 'JobsW_2007', 'ArtSupport_2007', 'JobsT_2008', 'ArtsW_2008', 'JobsW_2008',
 'ArtSupport_2008', 'JobsT_2009', 'ArtsW_2009', 'JobsW_2009', 'ArtSupport_2009', 'JobsT_2010', 'ArtsW_2010', 'JobsW_2010',
 'ArtSupport_2010', 'JobsT_2011', 'ArtsW_2011', 'JobsW_2011', 'ArtSupport_2011', 'JobsT_2012', 'ArtsW_2012', 'JobsW_2012',
 'ArtSupport_2012', 'JobsT_2013', 'ArtsW_2013', 'JobsW_2013', 'ArtSupport_2013', 'JobsT_2014', 'ArtsW_2014',
 'JobsW_2014', 'ArtSupport_2014', 'ARTGOSLG98', 'City', 'State', 'Location', 'zipcode'], axis=1, inplace=True)

# Creating a change variables for the arts
df['arts_change'] = df['ArtsN_2014'] - df['ArtsN_1998']

# %%
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler

#Splitting the data into train and test datasets.

X, y = df.iloc[:, 1:].values, df.iloc[:, 0].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.fit_transform(X_test)

# %%
# Calculating the eigen values 

cov_mat = np.cov(X_train_std.T)
eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)
print('\nEigenvalues \n%s' % eigen_vals)
# Out:
# Eigenvalues
# [  3.05599969e+01   6.96107322e+00   6.28630153e+00   4.97503076e+00
#    3.74912865e+00   2.77114243e+00   2.22549527e+00   2.08971155e+00
#    1.61560448e+00   1.33393071e+00   1.19144287e+00   1.14685986e+00
#    9.92346683e-01   8.76764290e-01   8.00851803e-01   7.71920136e-01
#    6.59760403e-01   6.39285150e-01   5.73965034e-01   5.01710642e-01
#    4.97139685e-01   4.67290969e-01   4.19794627e-01   3.62173474e-01
#    3.34124990e-01   3.16080493e-01   3.11312907e-01   2.72750701e-01
#    2.52941057e-01   2.41773248e-01   2.17601622e-01   1.67729275e-01
#    1.55654130e-01   1.48953899e-01   1.41807741e-01   1.20144559e-01
#    1.13778601e-01   1.08843771e-01   9.72709860e-02   7.53593692e-02
#    8.44547747e-02   8.24897489e-02   6.57571199e-02   5.66553901e-02
#    4.65854862e-02   4.59230981e-02   3.97186781e-02   3.20358191e-02
#    1.89512587e-02   2.87752735e-02   2.54374826e-02   2.69717583e-02
#    1.68544430e-02   1.29376239e-02   1.12721809e-02   1.04603936e-02
#    9.28823695e-03   7.76356174e-03   7.24039322e-03   6.61880644e-03
#   -2.27458730e-16   5.34512898e-03   4.66933144e-03   4.24178956e-03
#    3.95475295e-03   3.36077098e-03   3.09451713e-03   2.27130409e-03
#    7.46044792e-04   1.89171968e-03   1.62416281e-03   1.43615991e-03
#    8.62743716e-04   1.02328335e-03   1.26659640e-03   9.36714103e-04]

# %%
#Plotting the eigenpairs

tot = sum(eigen_vals)
var_exp = [(i / tot) for i in sorted(eigen_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
plt.bar(range(1,77), var_exp, alpha=0.5, align='center', label='individual explained variance')
plt.step(range(1,77), cum_var_exp, where='mid', label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# The first principal component explains about 40% of the variance, and the other 50% is explained by the other variables in the dataset. But what is that thing?

# %%
#Sorting eigenpairs on descending order

eigen_pairs =[(np.abs(eigen_vals[i]),eigen_vecs[:,i]) 
              for i in range(len(eigen_vals))]
eigen_pairs.sort(reverse=True)

# %%
# Collect the two eigenvectors that correspond to the two largest values.

w= np.hstack((eigen_pairs[0][1][:, np.newaxis], eigen_pairs[1][1][:, np.newaxis]))
print('Matrix W:\n',w)
# Out:
# ('Matrix W:\n', array([[ 0.15581071, -0.05423527],
#        [ 0.16395881,  0.02453765],
#        [ 0.15564654, -0.06000013],
#        [ 0.16441524,  0.03065231],
#        [ 0.16012409, -0.04663234],
#        [ 0.16462989,  0.03457614],
#        [ 0.16051457, -0.04985287],
#        [ 0.16402154,  0.04080835],
#        [ 0.1553126 , -0.04732974],
#        [ 0.16533021,  0.03668374],
#        [ 0.1578741 , -0.0619513 ],
#        [ 0.16566037,  0.04055005],
#        [ 0.15798942, -0.06810397],
#        [ 0.1662299 ,  0.04038931],
#        [ 0.15768176, -0.06794084],
#        [ 0.16608508,  0.04163801],
#        [ 0.16207189, -0.05724063],
#        [ 0.16544213,  0.04127375],
#        [ 0.16026057, -0.07255354],
#        [ 0.16685893,  0.03494998],
#        [ 0.15673577, -0.0834    ],
#        [ 0.16568151,  0.04147546],
#        [ 0.1558394 , -0.0861864 ],
#        [ 0.16587238,  0.03925696],
#        [ 0.15476572, -0.08727138],
#        [ 0.16665138,  0.03871293],
#        [ 0.15322225, -0.08484383],
#        [ 0.16691429,  0.03521405],
#        [ 0.15219203, -0.09450212],
#        [ 0.1660276 ,  0.04094098],
#        [ 0.15255833, -0.08370385],
#        [ 0.16541734,  0.04538423],
#        [ 0.14807856, -0.08785462],
#        [ 0.16647299,  0.04166481],
#        [-0.03953903,  0.11301236],
#        [ 0.04745131,  0.1845982 ],
#        [ 0.06328933, -0.04112022],
#        [ 0.03719012,  0.26877494],
#        [-0.00301271,  0.26795148],
#        [-0.01852944,  0.12912997],
#        [-0.07277172,  0.01972998],
#        [-0.07878015,  0.03639372],
#        [-0.02200839,  0.00356283],
#        [-0.08060735,  0.1699276 ],
#        [-0.03832205,  0.02545755],
#        [ 0.02689175, -0.18124085],
#        [ 0.01927364,  0.06620422],
#        [ 0.08656259, -0.14785754],
#        [ 0.04402859, -0.23913916],
#        [ 0.03593082, -0.05635142],
#        [-0.04787846,  0.10517872],
#        [ 0.03681249, -0.16450994],
#        [ 0.04041928, -0.01699142],
#        [ 0.04567698, -0.00395324],
#        [ 0.07150455,  0.05211419],
#        [ 0.0310366 ,  0.1970765 ],
#        [ 0.02865898, -0.00108581],
#        [ 0.04185716, -0.06303843],
#        [ 0.04913912,  0.1710013 ],
#        [ 0.05933952, -0.00249389],
#        [-0.07486168, -0.20449111],
#        [ 0.01547937,  0.14033153],
#        [ 0.08079625,  0.12134616],
#        [-0.00572056, -0.16658572],
#        [-0.05950224, -0.23333809],
#        [-0.06457733, -0.20241174],
#        [ 0.05432471,  0.01370584],
#        [-0.03423827,  0.03260041],
#        [-0.01047178,  0.07738965],
#        [ 0.04530906,  0.14726914],
#        [ 0.05539693,  0.1719855 ],
#        [-0.07161194, -0.12331501],
#        [ 0.06317318,  0.21164162],
#        [ 0.08111897,  0.20917145],
#        [-0.06031554, -0.20787957],
#        [ 0.07857076, -0.09421781]]))

# %%
X_train_std[0].dot(w)
X_train_pca = X_train_std.dot(w)

# %%
colors = ['r', 'b', 'g']
markers = ['s', 'x', 'o']
for l, c, m in zip(np.unique(y_train), colors, markers):
    plt.scatter(X_train_pca[y_train==l, 0],
                X_train_pca[y_train==l, 1], 
                c=c, label=l, marker=m)
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# This PCA analysis did not show us much.

# %% [markdown]
# ### PCA on scikit-learn

# %%
from matplotlib.colors import ListedColormap
def plot_decision_regions(X, y, classifier, resolution=0.02):
    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
    np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
        alpha=0.8, c=cmap(idx), marker=markers[idx], label=cl)

# %%
### Seems right, but this almost exploded my computer!!! 

from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
lr = LogisticRegression()
X_train_pca = pca.fit_transform(X_train_std)

X_test_pca = pca.transform(X_test_std)


lr.fit(X_train_pca, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# This part takes about 30 minutes to run, and show an error, and a clustering plot that says very little. 
# IndexError: tuple index out of range

plot_decision_regions(X_train_pca, y_train, classifier=lr)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(loc='lower left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-148-7aac145595e6> in <module>()
#       2 # IndexError: tuple index out of range
#       3
# ----> 4 plot_decision_regions(X_train_pca, y_train, classifier=lr)
#       5 plt.xlabel('PC1')
#       6 plt.ylabel('PC2')
#
# <ipython-input-146-6a353d85856b> in plot_decision_regions(X, y, classifier, resolution)
#      18     for idx, cl in enumerate(np.unique(y)):
#      19         plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
# ---> 20         alpha=0.8, c=cmap(idx), marker=markers[idx], label=cl)
#
# IndexError: tuple index out of range

# %% [markdown]
# ## Time Series Analysis

# %%
# Loading the data file in the LONG format. (Created in R)
df_long = pd.read_csv("nomisslong_sample.csv")

df_long['Total'] = df_long['ArtsN'] + df_long['JobsN']

# %%
df_long.head()
# Out:
#    Unnamed: 0    zip  MedAge2k    pctba2k    pctba90  racediversity2k  \
# 0  84124.1998  84124      37.4  42.130080  10.029895         0.160963
# 1   6239.1998   6239      36.4  13.127827  13.097893         0.145565
# 2  48236.1998  48236      42.3  55.610538  48.767123         0.123786
# 3  53203.1998  53203      34.9  60.269360  27.821522         0.374926
# 4  33917.1998  33917      52.4  13.231327  29.408242         0.099343
#
#    racediversity90  medrent2k  medrent90  medhhinc2k  ...    Corporateness  \
# 0         0.151323        699        483       55032  ...       397.038462
# 1         0.089482        520        505       39894  ...       249.696970
# 2         0.060418        812        509       82567  ...       918.470588
# 3         0.514221        788        360       50875  ...       762.612500
# 4         0.054643        569        590       33120  ...       173.740385
#
#     Ethnicity  time  JobsT  ArtsN  ArtsW  JobsN  JobsW  ArtSupport  Total
# 0  368.423077  1998   8713    123    688   8590   8025         565   8713
# 1  240.000000  1998   2861     13    170   2848   2691         157   2861
# 2  883.647059  1998  14878    312   1553  14566  13325        1241  14878
# 3  728.650000  1998  18751    379   3623  18372  15128        3244  18751
# 4  169.903846  1998   2604     53    193   2551   2411         140   2604
#
# [5 rows x 76 columns]

# %%
# How to make pandas understand that this is a years column so that I can use the resampling, and be sure it is using 
# year, not zip code.

# Trying with period objects.
df_long["time"] = pd.Period(df_long["time"], freq="a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-a9340d6fb75d> in <module>()
#       2 # year, not zip code.
#       3
# ----> 4 df_long["time"] = pd.Period(df_long["time"], freq="a")
#
# pandas/src/period.pyx in pandas._period.Period.__init__ (pandas/src/period.c:11369)()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __hash__(self)
#     799     def __hash__(self):
#     800         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 801                         ' hashed'.format(self.__class__.__name__))
#     802
#     803     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %% [markdown]
# Trying to make the time column be understood as year, but I can't! Any plot that I make will show by zip code, not by time. How to resample in this case?

# %%
# If not specified, the graph showss how arts varies per zip code. 

df_long['ArtsN'].plot()

# %% [markdown]
# There is no clear seasonality between the years, in either arts or jobs. But how can I improve these graphs?

# %%
# If not specified, the graph showss how arts varies per zip code. 

X = df_long['time']
y = df_long['ArtsN']

plt.plot(X, y)

# %% [markdown]
# How can I improve this graph too?
