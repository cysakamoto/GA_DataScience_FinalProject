# %% [markdown]
# # Data Science Final Project

# %% [markdown]
# # Introduction

# %% [markdown]
# In this project, I aim to further the analysis for my arts and jobs paper. The overall research question is: what drives growth, jobs or amenities? Do people follow jobs or amenities or both?
#
# Using regression analysis in the previous paper, I found that arts are drivers of growth. However, it is stronger in some places than others; for example, in more populated areas, or areas with more college graduates. But what really are the underelying variables that would distinguish the influence of the arts in one places than in others? What variables would be more relevant in the jobs and amenities to explain growth? In other words, <b> why are arts where they are?</b>
#
# With over 50 control variables available, I would like to know which ones would help describe the changes better than only the main regression variables. And here I use some methods to see what variables could explain the impact of the arts on the growth of jobs.

# %%
#Loading the packages

# %matplotlib inline
from collections import Counter
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans, DBSCAN
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import linear_model, metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# # The Data

# %% [markdown]
# The main data show the number of arts and non-arts jobs per zip code. The data is from the County Business Patterns, from the Census, and data ranges from 1998 to 2014.

# %%
#Loading the datafile. This is just a sample of the data. N=500
df = pd.read_csv("nomiss_sample.csv")

# Dropping unnecessary variables (Some string variables too, like names of the zip code location)
df.drop(['pctba90', 'racediversity90', 'medrent90', 'medhhinc90', 'meantrav90', 'meanlengthres90', 'pctsamehouse90',
'pctfemale90', 'pctmarried90', 'pctchild90', 'pctunemp90', 'diversityanc90', 'pctrental90', 'pctpov90', 'pctbike90',
'pctdrove90', 'pctwalk90', 'density1990', 'housingdensity1990', 'Pop1990', 'Unnamed: 0','JobsT_1998', 'ArtsW_1998', 'JobsW_1998', 
'ArtSupport_1998', 'JobsT_1999', 'ArtsW_1999', 'JobsW_1999', 'ArtSupport_1999', 'JobsT_2000', 'ArtsW_2000', 'JobsW_2000',
 'ArtSupport_2000', 'JobsT_2001', 'ArtsW_2001', 'JobsW_2001', 'ArtSupport_2001', 'JobsT_2002', 'ArtsW_2002', 'JobsW_2002',
 'ArtSupport_2002', 'JobsT_2003', 'ArtsW_2003', 'JobsW_2003', 'ArtSupport_2003', 'JobsT_2004', 'ArtsW_2004', 'JobsW_2004',
 'ArtSupport_2004', 'JobsT_2005', 'ArtsW_2005', 'JobsW_2005', 'ArtSupport_2005', 'JobsT_2006', 'ArtsW_2006', 'JobsW_2006',
 'ArtSupport_2006', 'JobsT_2007', 'ArtsW_2007', 'JobsW_2007', 'ArtSupport_2007', 'JobsT_2008', 'ArtsW_2008', 'JobsW_2008',
 'ArtSupport_2008', 'JobsT_2009', 'ArtsW_2009', 'JobsW_2009', 'ArtSupport_2009', 'JobsT_2010', 'ArtsW_2010', 'JobsW_2010',
 'ArtSupport_2010', 'JobsT_2011', 'ArtsW_2011', 'JobsW_2011', 'ArtSupport_2011', 'JobsT_2012', 'ArtsW_2012', 'JobsW_2012',
 'ArtSupport_2012', 'JobsT_2013', 'ArtsW_2013', 'JobsW_2013', 'ArtSupport_2013', 'JobsT_2014', 'ArtsW_2014',
 'JobsW_2014', 'ArtSupport_2014', 'ARTGOSLG98', 'RentMed', 'City', 'State', 'Location', 'zipcode'], axis=1, inplace=True)

# Creating change variable for arts
df['arts_change'] = df['ArtsN_2014'] - df['ArtsN_1998']

# Creating change variable for jobs
df['jobs_change'] = df['ArtsN_2014'] - df['ArtsN_1998']

# %%
#Listing the variables in the data.b
list(df.columns.values)
# Out:
# ['zip',
#  'ArtsN_1998',
#  'JobsN_1998',
#  'ArtsN_1999',
#  'JobsN_1999',
#  'ArtsN_2000',
#  'JobsN_2000',
#  'ArtsN_2001',
#  'JobsN_2001',
#  'ArtsN_2002',
#  'JobsN_2002',
#  'ArtsN_2003',
#  'JobsN_2003',
#  'ArtsN_2004',
#  'JobsN_2004',
#  'ArtsN_2005',
#  'JobsN_2005',
#  'ArtsN_2006',
#  'JobsN_2006',
#  'ArtsN_2007',
#  'JobsN_2007',
#  'ArtsN_2008',
#  'JobsN_2008',
#  'ArtsN_2009',
#  'JobsN_2009',
#  'ArtsN_2010',
#  'JobsN_2010',
#  'ArtsN_2011',
#  'JobsN_2011',
#  'ArtsN_2012',
#  'JobsN_2012',
#  'ArtsN_2013',
#  'JobsN_2013',
#  'ArtsN_2014',
#  'JobsN_2014',
#  'MedAge2k',
#  'pctba2k',
#  'racediversity2k',
#  'medrent2k',
#  'medhhinc2k',
#  'meantrav2k',
#  'medlengthres2k',
#  'pctsamehouse2k',
#  'pctfemale2k',
#  'pctmarried2k',
#  'pctchild2k',
#  'pctunemp2k',
#  'diversityfb2k',
#  'pctrental2k',
#  'pctpov2k',
#  'pctbike2k',
#  'pctdrove2k',
#  'pctwalk2k',
#  'density2000',
#  'housingdensity2000',
#  'Pop2000',
#  'Democ92',
#  'NonWhite_90',
#  'CollProfLv90',
#  'CrimeRate1999county',
#  'Traditionalistic',
#  'Self_Expressive',
#  'Utilitarian',
#  'Charismatic',
#  'Egalitarian',
#  'Neighborly',
#  'Formality',
#  'Exhibitionism',
#  'Glamorous',
#  'Transgressive',
#  'Rational',
#  'Locality',
#  'State_Scenes',
#  'Corporateness',
#  'Ethnicity',
#  'arts_change',
#  'jobs_change']

# %% [markdown]
# ## Defining the variables

# %%
# Defining core variables 

core = ['Pop2000', 'CrimeRate1999county', 'Democ92', 'NonWhite_90', 'CollProfLv90']

# Defining scenes variables

scenes = ['Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 'Neighborly', 'Formality',
'Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 'Corporateness', 'Ethnicity']

# Defining Geolytics variables 

geo = ['MedAge2k', 'pctba2k', 'racediversity2k', 'medrent2k', 'medhhinc2k', 'meantrav2k', 'medlengthres2k',
 'pctsamehouse2k', 'pctfemale2k', 'pctmarried2k', 'pctchild2k', 'pctunemp2k', 'diversityfb2k', 'pctrental2k',
 'pctpov2k', 'pctbike2k', 'pctdrove2k', 'pctwalk2k', 'density2000', 'housingdensity2000']

# Geolytics and core 

geo_core = ['MedAge2k', 'pctba2k', 'racediversity2k', 'medrent2k', 'medhhinc2k', 'meantrav2k', 'medlengthres2k',
 'pctsamehouse2k', 'pctfemale2k', 'pctmarried2k', 'pctchild2k', 'pctunemp2k', 'diversityfb2k', 'pctrental2k',
 'pctpov2k', 'pctbike2k', 'pctdrove2k', 'pctwalk2k', 'density2000', 'housingdensity2000', 
 'Pop2000', 'CrimeRate1999county', 'Democ92', 'NonWhite_90', 'CollProfLv90']

# Defining Arts and Jobs variables 

arts_jobs = ['ArtsN_1998', 'JobsN_1998', 'ArtsN_1999', 'JobsN_1999', 'ArtsN_2000', 'JobsN_2000', 'ArtsN_2001', 'JobsN_2001',
 'ArtsN_2002', 'JobsN_2002', 'ArtsN_2003', 'JobsN_2003', 'ArtsN_2004', 'JobsN_2004', 'ArtsN_2005', 'JobsN_2005',
 'ArtsN_2006', 'JobsN_2006', 'ArtsN_2007', 'JobsN_2007', 'ArtsN_2008', 'JobsN_2008', 'ArtsN_2009', 'JobsN_2009',
 'ArtsN_2010', 'JobsN_2010', 'ArtsN_2011', 'JobsN_2011', 'ArtsN_2012', 'JobsN_2012', 'ArtsN_2013', 'JobsN_2013']

# Defining all variables

all_var = ['Pop2000', 'CrimeRate1999county', 'Democ92', 'NonWhite_90', 'CollProfLv90', 'Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 'Neighborly', 'Formality',
'Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 'Corporateness', 'Ethnicity', 'MedAge2k', 'pctba2k', 'racediversity2k', 'medrent2k', 'medhhinc2k', 'meantrav2k', 'medlengthres2k',
 'pctsamehouse2k', 'pctfemale2k', 'pctmarried2k', 'pctchild2k', 'pctunemp2k', 'diversityfb2k', 'pctrental2k',
 'pctpov2k', 'pctbike2k', 'pctdrove2k', 'pctwalk2k', 'density2000', 'housingdensity2000', 'ArtsN_1998', 'JobsN_1998', 'ArtsN_1999', 'JobsN_1999', 'ArtsN_2000', 'JobsN_2000', 'ArtsN_2001', 'JobsN_2001',
 'ArtsN_2002', 'JobsN_2002', 'ArtsN_2003', 'JobsN_2003', 'ArtsN_2004', 'JobsN_2004', 'ArtsN_2005', 'JobsN_2005',
 'ArtsN_2006', 'JobsN_2006', 'ArtsN_2007', 'JobsN_2007', 'ArtsN_2008', 'JobsN_2008', 'ArtsN_2009', 'JobsN_2009',
 'ArtsN_2010', 'JobsN_2010', 'ArtsN_2011', 'JobsN_2011', 'ArtsN_2012', 'JobsN_2012', 'ArtsN_2013', 'JobsN_2013']

# %% [markdown]
# ## What are the arts?
#
# The arts are defined as sum of the number of jobs in the following categories:
#
# <img src="Categories.png" alt="Categories">
#
# But here I only focus on the narrow categories.

# %%
#Number of observations, number of variables

df.shape
# Out:
# (500, 77)

# %% [markdown]
# ### Variables

# %% [markdown]
# Below is the data description of the 2014 <b> main variables </b> for the arts and non-arts jobs.

# %%
df.describe()
# Out:
#                 zip   ArtsN_1998    JobsN_1998   ArtsN_1999    JobsN_1999  \
# count    500.000000   500.000000    500.000000   500.000000    500.000000
# mean   42583.684000   150.830000   8940.380000   160.466000   9186.372000
# std    27367.141769   323.254804   9304.431677   342.380288   9650.718247
# min     1013.000000     3.000000      3.000000     3.000000      3.000000
# 25%    19117.750000    18.000000   2244.500000    19.000000   2293.250000
# 50%    37897.000000    57.000000   6045.500000    60.000000   6091.500000
# 75%    65377.000000   149.000000  12168.500000   158.000000  12656.250000
# max    94041.000000  3375.000000  60042.000000  3383.000000  60907.000000
#
#        ArtsN_2000    JobsN_2000   ArtsN_2001    JobsN_2001   ArtsN_2002  \
# count   500.00000    500.000000   500.000000    500.000000   500.000000
# mean    167.50600   9387.514000   174.880000   9478.936000   156.222000
# std     348.97262   9903.400697   374.091473  10144.184508   305.716112
# min       3.00000      0.000000     3.000000      0.000000     3.000000
# 25%      19.00000   2319.000000    21.000000   2356.250000    16.000000
# 50%      67.50000   6141.500000    66.500000   6280.000000    61.000000
# 75%     171.00000  13150.750000   175.250000  12867.250000   171.500000
# max    3431.00000  66534.000000  4312.000000  76758.000000  2784.000000
#
#           ...         Formality  Exhibitionism    Glamorous  Transgressive  \
# count     ...        500.000000     500.000000   500.000000     500.000000
# mean      ...        428.190351     425.885760   422.153434     380.971538
# std       ...        373.947893     370.575748   369.627462     333.706941
# min       ...          3.000000       3.250000     3.000000       2.750000
# 25%       ...        160.247997     160.513941   156.401442     142.726157
# 50%       ...        325.698861     322.408153   319.159864     287.851017
# 75%       ...        592.038651     588.692797   586.211349     530.333984
# max       ...       2696.743056    2666.812500  2671.302083    2417.640625
#
#           Rational     Locality  State_Scenes  Corporateness    Ethnicity  \
# count   500.000000   500.000000    500.000000     500.000000   500.000000
# mean    406.706685   412.728461    408.390568     432.219519   408.493403
# std     354.157323   358.124086    356.844095     379.424845   355.585790
# min       3.000000     3.250000      3.000000       3.000000     3.000000
# 25%     154.257560   157.562317    154.322140     160.095709   154.951172
# 50%     308.450483   314.277590    307.687775     326.498743   306.780798
# 75%     563.734064   570.901549    565.753714     597.548034   566.166667
# max    2571.034722  2588.244792   2583.755208    2740.890625  2581.510417
#
#        arts_change
# count   500.000000
# mean     37.292000
# std     256.700536
# min   -3073.000000
# 25%     -10.250000
# 50%       7.000000
# 75%      65.000000
# max    2205.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# Some of the main <b> control variables </b> are listed below. The first table shows the core variables, which are from Prof. Clark's Scenes Project.

# %% [markdown]
# | Variable | Description  |
# |------|------|
# | Pop2000 | Population in 2000 |
# | CrimeRate1999county | Crime Rate in 1999 |
# | Democ92 | Percent Democrats |
# | RentMed | Median Rent |
# | NonWhite_90 | Percent non white population in 1990 |
# | CollProfLv90 | Percent college graduates in 1990 |

# %%
# Describing the variables
df[core].describe()
# Out:
#             Pop2000  CrimeRate1999county     Democ92   NonWhite_90  \
# count    500.000000           500.000000  500.000000    500.000000
# mean   19636.284000          4172.196000   41.663600   3123.410000
# std    14427.529156          2113.478098    9.440388   5221.593264
# min      169.000000           151.000000   17.100000      0.000000
# 25%     7965.250000          2522.750000   35.500000    177.750000
# 50%    16361.000000          3695.000000   40.300000    997.000000
# 75%    27855.250000          5653.000000   47.000000   3429.750000
# max    74948.000000          9834.000000   84.600000  38284.000000
#
#        CollProfLv90
# count    500.000000
# mean       0.227264
# std        0.137318
# min        0.031375
# 25%        0.125387
# 50%        0.184616
# 75%        0.291245
# max        0.753073

# %%
# Correlation of the variables
df[core].corr()
# Out:
#                       Pop2000  CrimeRate1999county   Democ92  NonWhite_90  \
# Pop2000              1.000000             0.388233  0.105133     0.547801
# CrimeRate1999county  0.388233             1.000000  0.303087     0.334000
# Democ92              0.105133             0.303087  1.000000     0.297978
# NonWhite_90          0.547801             0.334000  0.297978     1.000000
# CollProfLv90         0.072467             0.125662  0.193838    -0.067863
#
#                      CollProfLv90
# Pop2000                  0.072467
# CrimeRate1999county      0.125662
# Democ92                  0.193838
# NonWhite_90             -0.067863
# CollProfLv90             1.000000

# %% [markdown]
# The table below shows the <b> Scenes variables </b>, which are decoded into 15 dimensions. These variables were created by coders, who gave a score from 1 to 5 on each dimension based on the type of neighborhood (zip code) they were analyzing, and them summed. The coders followed a series of guidelines, but mostly trying to answer the question: <b> does an amenity’s vitality and energy comes from the way it embodies this sub-category? </b> Thus, coding whether an amenity positively or negatively indicated the concrete presence of the sub-category.
#
# The AP variables reflect "amenities performance", on the zip code level.

# %% [markdown]
# | Scenes Dimension | Type | Measurement Level | Description (Values) |
# |------|------|
#  | Traditionalistic | Numeric | Scale | Appeals to heritage and the past |
#  | Self_expressive | Numeric | Scale | Unique, personal, expression |
# | Utilitarian | Numeric | Scale | Usefulness of its amenities |
# | Charismatic | Numeric | Scale | In the presence of an exceptional personality |
#  | Egalitarian | Numeric | Scale | Universal equality, treating others non-strategically |
#  | Neighborly | Numeric | Scale | Closeness, personal networks, face-to-face interactions |
#  | Formality | Numeric | Scale | Fitting into established patterns of social etiquette |
# | Exhibitionism | Numeric | Scale | Encourage looking at others and being looked by them in turn |
#  | Glamorous | Numeric | Scale | Charm, allure, star power, status |
#  | Transgressive | Numeric | Scale | Revel in shocking others and associating with equally shocking others |
#  | Rational | Numeric | Scale | Power to choose one's own fate (organic or planned growth)|
# | Locality | Numeric | Scale | Feeling rooted in a place |
# | State | Numeric | Scale | Role of the State in shaping one's identity |
#  | Corporateness | Numeric | Scale | Corporations as social power that shape identity |
#  | Ethnicity | Numeric | Scale | Shape of pre-reflective identity |

# %%
df[scenes].describe()
# Out:
#        Traditionalistic  Self_Expressive  Utilitarian  Charismatic  \
# count        500.000000       500.000000   500.000000   500.000000
# mean         417.377171       434.301216   392.292006   437.808753
# std          363.143478       382.261930   343.281785   385.144623
# min            3.250000         3.000000     2.500000     3.000000
# 25%          156.508065       161.685847   145.027920   163.102697
# 50%          315.884978       325.950581   297.807432   331.497271
# 75%          576.197917       602.285330   542.777123   611.772682
# max         2615.182292      2756.604167  2498.453125  2792.520833
#
#        Egalitarian   Neighborly    Formality  Exhibitionism    Glamorous  \
# count   500.000000   500.000000   500.000000     500.000000   500.000000
# mean    418.064375   416.261428   428.190351     425.885760   422.153434
# std     363.300658   360.998430   373.947893     370.575748   369.627462
# min       3.000000     3.000000     3.000000       3.250000     3.000000
# 25%     158.646925   157.591482   160.247997     160.513941   156.401442
# 50%     318.198931   314.161683   325.698861     322.408153   319.159864
# 75%     581.017506   579.726789   592.038651     588.692797   586.211349
# max    2615.182292  2606.951389  2696.743056    2666.812500  2671.302083
#
#        Transgressive     Rational     Locality  State_Scenes  Corporateness  \
# count     500.000000   500.000000   500.000000    500.000000     500.000000
# mean      380.971538   406.706685   412.728461    408.390568     432.219519
# std       333.706941   354.157323   358.124086    356.844095     379.424845
# min         2.750000     3.000000     3.250000      3.000000       3.000000
# 25%       142.726157   154.257560   157.562317    154.322140     160.095709
# 50%       287.851017   308.450483   314.277590    307.687775     326.498743
# 75%       530.333984   563.734064   570.901549    565.753714     597.548034
# max      2417.640625  2571.034722  2588.244792   2583.755208    2740.890625
#
#          Ethnicity
# count   500.000000
# mean    408.493403
# std     355.585790
# min       3.000000
# 25%     154.951172
# 50%     306.780798
# 75%     566.166667
# max    2581.510417

# %%
df[scenes].corr()
# Out:
#                   Traditionalistic  Self_Expressive  Utilitarian  Charismatic  \
# Traditionalistic          1.000000         0.999888     0.999471     0.999880
# Self_Expressive           0.999888         1.000000     0.999297     0.999935
# Utilitarian               0.999471         0.999297     1.000000     0.999469
# Charismatic               0.999880         0.999935     0.999469     1.000000
# Egalitarian               0.999899         0.999798     0.999537     0.999809
# Neighborly                0.999942         0.999838     0.999562     0.999851
# Formality                 0.999898         0.999830     0.999630     0.999855
# Exhibitionism             0.999930         0.999847     0.999418     0.999830
# Glamorous                 0.999894         0.999918     0.999473     0.999921
# Transgressive             0.999812         0.999833     0.999396     0.999842
# Rational                  0.999822         0.999706     0.999655     0.999747
# Locality                  0.999886         0.999799     0.999283     0.999769
# State_Scenes              0.999958         0.999876     0.999568     0.999884
# Corporateness             0.999761         0.999729     0.999541     0.999776
# Ethnicity                 0.999971         0.999895     0.999479     0.999890
#
#                   Egalitarian  Neighborly  Formality  Exhibitionism  \
# Traditionalistic     0.999899    0.999942   0.999898       0.999930
# Self_Expressive      0.999798    0.999838   0.999830       0.999847
# Utilitarian          0.999537    0.999562   0.999630       0.999418
# Charismatic          0.999809    0.999851   0.999855       0.999830
# Egalitarian          1.000000    0.999917   0.999836       0.999840
# Neighborly           0.999917    1.000000   0.999900       0.999912
# Formality            0.999836    0.999900   1.000000       0.999863
# Exhibitionism        0.999840    0.999912   0.999863       1.000000
# Glamorous            0.999810    0.999874   0.999903       0.999888
# Transgressive        0.999795    0.999860   0.999777       0.999813
# Rational             0.999886    0.999913   0.999835       0.999762
# Locality             0.999799    0.999882   0.999778       0.999826
# State_Scenes         0.999867    0.999940   0.999906       0.999916
# Corporateness        0.999616    0.999672   0.999799       0.999703
# Ethnicity            0.999886    0.999934   0.999885       0.999924
#
#                   Glamorous  Transgressive  Rational  Locality  State_Scenes  \
# Traditionalistic   0.999894       0.999812  0.999822  0.999886      0.999958
# Self_Expressive    0.999918       0.999833  0.999706  0.999799      0.999876
# Utilitarian        0.999473       0.999396  0.999655  0.999283      0.999568
# Charismatic        0.999921       0.999842  0.999747  0.999769      0.999884
# Egalitarian        0.999810       0.999795  0.999886  0.999799      0.999867
# Neighborly         0.999874       0.999860  0.999913  0.999882      0.999940
# Formality          0.999903       0.999777  0.999835  0.999778      0.999906
# Exhibitionism      0.999888       0.999813  0.999762  0.999826      0.999916
# Glamorous          1.000000       0.999822  0.999752  0.999751      0.999898
# Transgressive      0.999822       1.000000  0.999800  0.999799      0.999832
# Rational           0.999752       0.999800  1.000000  0.999795      0.999830
# Locality           0.999751       0.999799  0.999795  1.000000      0.999876
# State_Scenes       0.999898       0.999832  0.999830  0.999876      1.000000
# Corporateness      0.999806       0.999579  0.999556  0.999552      0.999820
# Ethnicity          0.999903       0.999854  0.999812  0.999884      0.999969
#
#                   Corporateness  Ethnicity
# Traditionalistic       0.999761   0.999971
# Self_Expressive        0.999729   0.999895
# Utilitarian            0.999541   0.999479
# Charismatic            0.999776   0.999890
# Egalitarian            0.999616   0.999886
# Neighborly             0.999672   0.999934
# Formality              0.999799   0.999885
# Exhibitionism          0.999703   0.999924
# Glamorous              0.999806   0.999903
# Transgressive          0.999579   0.999854
# Rational               0.999556   0.999812
# Locality               0.999552   0.999884
# State_Scenes           0.999820   0.999969
# Corporateness          1.000000   0.999775
# Ethnicity              0.999775   1.000000

# %% [markdown]
# PS: The scenes variables are highly correlated. May be causing some multicollinearity on the analysis. <br/>
# I am asking my advisor why and if we have better data...

# %% [markdown]
# Other variables of interest are from the <b> Geolytics database </b>, also in the zip code level. Some variables are described in the table below.

# %% [markdown]
# | Variable | Type | Measurement Level | Description  |
# |------|------|
# | pctba2k  | Numeric | Scale | Percent Graduated Bachelor Degree in 2000 |
# | pctrental2k | Numeric | Scale | Percent Rentals in 2000 |
# | pctmarried2k | Numeric | Scale | Percent of population 15 years and older, married, 2000 |
# | pctchild2k | Numeric | Scale | Percentage of households with children 0-17, 2000 |
# | racediversity2k | Numeric | Scale | Racial diversity index, 2000 |
# | medrent2k | Numeric | Scale | Median Gross Rent, 2000 |
# | medhhinc2k | Numeric | Scale | Median Household Income, 2000 |
# | meantrav2k | Numeric | Scale | Mean travel time to work in minutes, 2000 |
# | medlengthres2k | Numeric | Scale | Median length of residence in housing unit, 2000 |
# | pctsamehouse2k | Numeric | Scale | Percentage living in same house, from 1995 to 2000 |
# | pctfemale2k | Numeric | Scale | Percentage female, 2000 |
# | pctunemp2k | Numeric | Scale | Percentage of unemployed labor force, 2000 |
# | diversityfb2k | Numeric | Scale | Foreign born diversity index, 2000 |
# | pctpov2k | Numeric | Scale | Percentage population below poverty level, 2000 |
# | pctwalk2k | Numeric | Scale | Percent of people who walk in 2000 |
# | pctbike2k | Numeric | Scale | Percentage biked to work, 2000 |
# | pctdrove2k | Numeric | Scale | Percentage drove to work, 2000 |
# | density2000 | Numeric | Scale | Population density, 2000 |
# | housingdensity2000 | Numeric | Scale | Housing density, 2000 |

# %%
# Description of the Geolytics variables

df[geo].describe()
# Out:
#          MedAge2k     pctba2k  racediversity2k    medrent2k     medhhinc2k  \
# count  500.000000  500.000000       500.000000   500.000000     500.000000
# mean    36.891000   26.909316         0.303079   628.660000   47667.866000
# std      4.740388   15.625101         0.217207   256.902523   20646.054933
# min     23.600000    3.491858         0.000000     0.000000   13750.000000
# 25%     33.900000   14.615629         0.111948   464.000000   34334.250000
# 50%     36.900000   22.620498         0.253954   578.000000   42141.500000
# 75%     39.725000   36.713185         0.485239   724.500000   55754.000000
# max     60.900000   89.264582         0.820607  2001.000000  200001.000000
#
#        meantrav2k  medlengthres2k  pctsamehouse2k  pctfemale2k  pctmarried2k  \
# count  500.000000      500.000000      500.000000   500.000000    500.000000
# mean    24.797622        6.496000       54.990751    51.107193     57.934490
# std      5.994989        2.798866       10.743090     2.039138      8.762532
# min      9.270833        1.000000       16.486903    41.011469     26.544868
# 25%     20.658239        4.000000       48.395124    50.204079     52.874223
# 50%     24.179289        6.000000       56.414344    51.220897     59.766381
# 75%     28.559107        8.000000       62.810957    52.231527     63.815563
# max     49.492559       20.000000       78.911565    58.937824     78.486029
#
#        pctchild2k  pctunemp2k  diversityfb2k  pctrental2k    pctpov2k  \
# count  500.000000  500.000000     500.000000   500.000000  500.000000
# mean    32.991680    5.056689       0.529804    30.812538   10.616542
# std      7.813197    2.983801       0.175180    16.516941    7.455272
# min      4.219409    0.000000       0.000000     1.749781    0.000000
# 25%     28.356874    3.111566       0.465759    20.080954    4.701980
# 50%     32.748370    4.369898       0.599565    27.171007    8.817120
# 75%     37.598388    6.013019       0.650161    37.722073   14.070782
# max     59.903148   25.687871       0.738424    93.349726   43.606904
#
#         pctbike2k  pctdrove2k   pctwalk2k   density2000  housingdensity2000
# count  500.000000  500.000000  500.000000    500.000000          500.000000
# mean     0.292774   89.348023    2.806996   2066.432098          863.736676
# std      0.482455    8.788051    4.169013   3701.035893         1524.912647
# min      0.000000   18.479222    0.000000      0.274497            0.193285
# 25%      0.000000   87.787440    1.005617    136.484131           60.820234
# 50%      0.144529   91.854515    1.788778    671.308444          285.174755
# 75%      0.358641   94.310450    3.320211   2711.326603         1127.422629
# max      3.433408   97.850163   61.007958  38914.335750        16976.740659

# %%
# Description of the Geolytics variables

df[geo].corr()
# Out:
#                     MedAge2k   pctba2k  racediversity2k  medrent2k  \
# MedAge2k            1.000000  0.125275        -0.522994   0.063628
# pctba2k             0.125275  1.000000        -0.039211   0.690816
# racediversity2k    -0.522994 -0.039211         1.000000   0.097373
# medrent2k           0.063628  0.690816         0.097373   1.000000
# medhhinc2k          0.202703  0.745347        -0.179565   0.811102
# meantrav2k         -0.017937  0.116644         0.084874   0.354762
# medlengthres2k      0.517391 -0.106945        -0.436289  -0.065610
# pctsamehouse2k      0.515449 -0.205742        -0.468090  -0.142087
# pctfemale2k         0.256524  0.058896        -0.054812   0.027340
# pctmarried2k        0.386744  0.105329        -0.480365   0.188671
# pctchild2k         -0.371570 -0.065804         0.078029   0.183745
# pctunemp2k         -0.270074 -0.385901         0.420675  -0.255398
# diversityfb2k       0.098834  0.342101        -0.184890   0.233313
# pctrental2k        -0.484500 -0.066789         0.537665  -0.163894
# pctpov2k           -0.382652 -0.445790         0.510487  -0.426984
# pctbike2k          -0.166175  0.100165         0.265243   0.042799
# pctdrove2k          0.100102 -0.321819        -0.259653  -0.203306
# pctwalk2k          -0.131098  0.183142         0.093957   0.016834
# density2000        -0.240047  0.092159         0.419611   0.135981
# housingdensity2000 -0.216899  0.120890         0.416525   0.121290
#
#                     medhhinc2k  meantrav2k  medlengthres2k  pctsamehouse2k  \
# MedAge2k              0.202703   -0.017937        0.517391        0.515449
# pctba2k               0.745347    0.116644       -0.106945       -0.205742
# racediversity2k      -0.179565    0.084874       -0.436289       -0.468090
# medrent2k             0.811102    0.354762       -0.065610       -0.142087
# medhhinc2k            1.000000    0.360404        0.139843        0.106851
# meantrav2k            0.360404    1.000000        0.035827        0.087078
# medlengthres2k        0.139843    0.035827        1.000000        0.868191
# pctsamehouse2k        0.106851    0.087078        0.868191        1.000000
# pctfemale2k          -0.027469   -0.128556        0.208508        0.241973
# pctmarried2k          0.482977    0.248666        0.295325        0.374839
# pctchild2k            0.336223    0.370711       -0.009388        0.124130
# pctunemp2k           -0.468972   -0.030124       -0.099948       -0.118956
# diversityfb2k         0.297171    0.054462       -0.080928       -0.053013
# pctrental2k          -0.465014   -0.214351       -0.529712       -0.594808
# pctpov2k             -0.660611   -0.173091       -0.230111       -0.233142
# pctbike2k            -0.134585   -0.223826       -0.264195       -0.332765
# pctdrove2k           -0.057529   -0.130956        0.082974        0.173017
# pctwalk2k            -0.136636   -0.226066       -0.104122       -0.266150
# density2000          -0.078206    0.187666       -0.163025       -0.204727
# housingdensity2000   -0.097591    0.157440       -0.190898       -0.246639
#
#                     pctfemale2k  pctmarried2k  pctchild2k  pctunemp2k  \
# MedAge2k               0.256524      0.386744   -0.371570   -0.270074
# pctba2k                0.058896      0.105329   -0.065804   -0.385901
# racediversity2k       -0.054812     -0.480365    0.078029    0.420675
# medrent2k              0.027340      0.188671    0.183745   -0.255398
# medhhinc2k            -0.027469      0.482977    0.336223   -0.468972
# meantrav2k            -0.128556      0.248666    0.370711   -0.030124
# medlengthres2k         0.208508      0.295325   -0.009388   -0.099948
# pctsamehouse2k         0.241973      0.374839    0.124130   -0.118956
# pctfemale2k            1.000000     -0.139712   -0.122359    0.072424
# pctmarried2k          -0.139712      1.000000    0.519433   -0.479617
# pctchild2k            -0.122359      0.519433    1.000000   -0.107714
# pctunemp2k             0.072424     -0.479617   -0.107714    1.000000
# diversityfb2k          0.119374      0.049798   -0.031789   -0.304644
# pctrental2k            0.005080     -0.824042   -0.407552    0.469564
# pctpov2k              -0.007138     -0.615212   -0.201850    0.763674
# pctbike2k             -0.114804     -0.397388   -0.264707    0.198197
# pctdrove2k            -0.015700      0.418548    0.277973   -0.238180
# pctwalk2k             -0.000842     -0.397186   -0.406834    0.208106
# density2000            0.091603     -0.454687   -0.117545    0.279835
# housingdensity2000     0.084803     -0.510826   -0.218314    0.258431
#
#                     diversityfb2k  pctrental2k  pctpov2k  pctbike2k  \
# MedAge2k                 0.098834    -0.484500 -0.382652  -0.166175
# pctba2k                  0.342101    -0.066789 -0.445790   0.100165
# racediversity2k         -0.184890     0.537665  0.510487   0.265243
# medrent2k                0.233313    -0.163894 -0.426984   0.042799
# medhhinc2k               0.297171    -0.465014 -0.660611  -0.134585
# meantrav2k               0.054462    -0.214351 -0.173091  -0.223826
# medlengthres2k          -0.080928    -0.529712 -0.230111  -0.264195
# pctsamehouse2k          -0.053013    -0.594808 -0.233142  -0.332765
# pctfemale2k              0.119374     0.005080 -0.007138  -0.114804
# pctmarried2k             0.049798    -0.824042 -0.615212  -0.397388
# pctchild2k              -0.031789    -0.407552 -0.201850  -0.264707
# pctunemp2k              -0.304644     0.469564  0.763674   0.198197
# diversityfb2k            1.000000    -0.126551 -0.376475  -0.015777
# pctrental2k             -0.126551     1.000000  0.619798   0.355583
# pctpov2k                -0.376475     0.619798  1.000000   0.261645
# pctbike2k               -0.015777     0.355583  0.261645   1.000000
# pctdrove2k               0.067141    -0.420859 -0.277315  -0.270197
# pctwalk2k               -0.099833     0.397331  0.300877   0.261813
# density2000             -0.034493     0.544057  0.264656   0.174132
# housingdensity2000       0.003071     0.580198  0.268659   0.196501
#
#                     pctdrove2k  pctwalk2k  density2000  housingdensity2000
# MedAge2k              0.100102  -0.131098    -0.240047           -0.216899
# pctba2k              -0.321819   0.183142     0.092159            0.120890
# racediversity2k      -0.259653   0.093957     0.419611            0.416525
# medrent2k            -0.203306   0.016834     0.135981            0.121290
# medhhinc2k           -0.057529  -0.136636    -0.078206           -0.097591
# meantrav2k           -0.130956  -0.226066     0.187666            0.157440
# medlengthres2k        0.082974  -0.104122    -0.163025           -0.190898
# pctsamehouse2k        0.173017  -0.266150    -0.204727           -0.246639
# pctfemale2k          -0.015700  -0.000842     0.091603            0.084803
# pctmarried2k          0.418548  -0.397186    -0.454687           -0.510826
# pctchild2k            0.277973  -0.406834    -0.117545           -0.218314
# pctunemp2k           -0.238180   0.208106     0.279835            0.258431
# diversityfb2k         0.067141  -0.099833    -0.034493            0.003071
# pctrental2k          -0.420859   0.397331     0.544057            0.580198
# pctpov2k             -0.277315   0.300877     0.264656            0.268659
# pctbike2k            -0.270197   0.261813     0.174132            0.196501
# pctdrove2k            1.000000  -0.687993    -0.539227           -0.556884
# pctwalk2k            -0.687993   1.000000     0.164273            0.195613
# density2000          -0.539227   0.164273     1.000000            0.976878
# housingdensity2000   -0.556884   0.195613     0.976878            1.000000

# %% [markdown]
# ## Plots

# %%
# How did the arts change over the years

sns.lmplot(x="ArtsN_2014", y="ArtsN_1998", data=df)
sns.plt.show()

# %%
# How did jobs change over the years 

sns.lmplot(x="JobsN_2014", y="JobsN_1998", data=df)
sns.plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# Differently from the analysis on the paper, in this project, the research question is: why are arts where they are? What makes some places more attractive for the arts than others?
#
# 1. Linear regression model (I and II)
# 2. Cross validation
# 3. Decision trees
# 4. Random forest
# 5. Cluster Analysis
# 6. Autocorrelation
# 7. Time Series

# %% [markdown]
# ## Linear Regression Model I

# %% [markdown]
# I start here with the linear regression model, since it is the simplest method to fitting the data. This was also used in my previous paper. The equation of this regression is:
#
# <center> $ Arts_{2014} = \alpha + \beta * Arts_{1998} + \gamma * Jobs_{1998} + Control Variables + \epsilon $ </center>
#
# I first start with only education as a control variable.

# %%
# Defining a linear model function. 

def linear_model_function(X, y):
    
    # Loading the package
    from sklearn import linear_model, metrics

    # Adding the intercept 
    X = sm.add_constant(X)
        
    # Fit the linear model
    model = linear_model.LinearRegression()
    results = model.fit(X, y)
    model = sm.OLS(y, X)
    results = model.fit()

    # Pring result
    print(results.summary())

# %%
X = df[["JobsN_1998", "ArtsN_1998", "CollProfLv90"]]
y = df["ArtsN_2014"]

linear_model_function(X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     214.3
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):           4.04e-89
# Time:                        12:18:26   Log-Likelihood:                -3434.3
# No. Observations:                 500   AIC:                             6877.
# Df Residuals:                     496   BIC:                             6893.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const          -59.4785     21.761     -2.733      0.006      -102.233   -16.724
# JobsN_1998       0.0078      0.001      6.057      0.000         0.005     0.010
# ArtsN_1998       0.6265      0.038     16.467      0.000         0.552     0.701
# CollProfLv90   368.2489     79.937      4.607      0.000       211.193   525.305
# ==============================================================================
# Omnibus:                      221.209   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25408.429
# Skew:                           0.876   Prob(JB):                         0.00
# Kurtosis:                      37.879   Cond. No.                     1.01e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# We see that all three independent variables are significant, so we can assume that education, non-arts jobs, and the arts had an impact in the growth of arts; with education having the highest impact of all three. This shows that on average education is important for the development of the arts, however, what else is?

# %% [markdown]
# ### Cross Validation

# %%
def cross_val_function(data, X, y):
    
    # Loading the package
    from sklearn import cross_validation

    # Defining the cross validation object
    kf = cross_validation.KFold(len(df), n_folds=5, shuffle=True)

    # Creating empty lists
    mse_values = []
    scores = []
    n = 0
    
    # Running the cross-validation
    print "~~~~ CROSS VALIDATION each fold ~~~~"
    for train_index, test_index in kf:
        lm = linear_model.LinearRegression().fit(X.iloc[train_index], y.iloc[train_index])
        mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(X.iloc[test_index])))
        scores.append(lm.score(X, y))
        n+=1
        print 'Model', n
        print 'MSE:', mse_values[n-1]
        print 'R2:', scores[n-1]


    print "~~~~ SUMMARY OF CROSS VALIDATION ~~~~"
    print 'Mean of MSE for all folds:', np.mean(mse_values)
    print 'Mean of R2 for all folds:', np.mean(scores)

# %%
cross_val_function(df, X, y)
# Out:
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 73087.9108241
# R2: 0.56244802764
# Model 2
# MSE: 31024.702615
# R2: 0.561645897463
# Model 3
# MSE: 70341.930477
# R2: 0.560989287623
# Model 4
# MSE: 14130.3810726
# R2: 0.563846937369
# Model 5
# MSE: 125663.47094
# R2: 0.531156521981
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 62849.6791857
# Mean of R2 for all folds: 0.556017334415

# %% [markdown]
# The cross-validation R2 for all folds are close to the R2 from the original model, so we can assume the original model is good.

# %% [markdown]
# ## Linear Regression Model II

# %% [markdown]
# In this second part, all the core variables are added as independent variables, to see which variables caused an impact on the arts.

# %%
X = df[["JobsN_1998", "ArtsN_1998", "CollProfLv90", "CrimeRate1999county", "Democ92", "NonWhite_90"]]
y = df["ArtsN_2014"]

linear_model_function(X, y)
cross_val_function(df, X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):           1.35e-86
# Time:                        12:18:33   Log-Likelihood:                -3432.2
# No. Observations:                 500   AIC:                             6878.
# Df Residuals:                     493   BIC:                             6908.
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# const                 -61.2849     50.475     -1.214      0.225      -160.457    37.887
# JobsN_1998              0.0076      0.001      5.560      0.000         0.005     0.010
# ArtsN_1998              0.6299      0.038     16.501      0.000         0.555     0.705
# CollProfLv90          350.7936     82.828      4.235      0.000       188.055   513.533
# CrimeRate1999county     0.0103      0.006      1.868      0.062        -0.001     0.021
# Democ92                -0.6848      1.230     -0.557      0.578        -3.101     1.731
# NonWhite_90            -0.0024      0.002     -1.059      0.290        -0.007     0.002
# ==============================================================================
# Omnibus:                      220.113   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24980.192
# Skew:                           0.869   Prob(JB):                         0.00
# Kurtosis:                      37.584   Cond. No.                     1.10e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 99196.0939734
# R2: 0.536227171942
# Model 2
# MSE: 149422.555472
# R2: 0.535312739685
# Model 3
# MSE: 28032.0288196
# R2: 0.566322530688
# Model 4
# MSE: 44708.6823
# R2: 0.564027423362
# Model 5
# MSE: 25123.757039
# R2: 0.564609633449
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 69296.6235208
# Mean of R2 for all folds: 0.553299899825

# %% [markdown]
# We see that again only education is significant on the impact of the arts, while the other variables show a p-value of over .05.
#
# If we remove rent, percent white, and crime rate, we have that percent democrats also have an impact on the arts.

# %%
# Defining variables
X = df[["JobsN_1998", "ArtsN_1998", "CollProfLv90", "Democ92"]]
y = df["ArtsN_2014"]

linear_model_function(X, y)
cross_val_function(df, X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     160.5
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):           5.94e-88
# Time:                        12:18:35   Log-Likelihood:                -3434.2
# No. Observations:                 500   AIC:                             6878.
# Df Residuals:                     495   BIC:                             6899.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const          -41.9468     49.191     -0.853      0.394      -138.597    54.703
# JobsN_1998       0.0078      0.001      6.038      0.000         0.005     0.010
# ArtsN_1998       0.6279      0.038     16.421      0.000         0.553     0.703
# CollProfLv90   373.4664     81.074      4.606      0.000       214.174   532.758
# Democ92         -0.4511      1.135     -0.397      0.691        -2.681     1.779
# ==============================================================================
# Omnibus:                      220.614   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25571.860
# Skew:                           0.867   Prob(JB):                         0.00
# Kurtosis:                      37.992   Cond. No.                     1.01e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 99918.3516175
# R2: 0.53736621162
# Model 2
# MSE: 45432.8631035
# R2: 0.560910178241
# Model 3
# MSE: 37133.4364173
# R2: 0.561762552148
# Model 4
# MSE: 57171.5718996
# R2: 0.563590509911
# Model 5
# MSE: 70177.7138925
# R2: 0.561178085555
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 61966.7873861
# Mean of R2 for all folds: 0.556961507495

# %% [markdown]
# Now all the variables are significant at 95%. The cross-validation shows that the R2 is lower than the original linear model, and closer to the first linear regression model, so I would have my doubts on keeping the Democ92 variable.

# %% [markdown]
# ## Models with Scenes Dimensions

# %% [markdown]
# Here I add the scenes dimensions variables.

# %%
#Dependent variable is arts: how did jobs and the other variables influence the growth of arts?

X = df[["JobsN_1998", "ArtsN_1998", 'Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 
        'Neighborly', 'Formality','Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 
        'Corporateness', 'Ethnicity']]
y = df["ArtsN_2014"]


linear_model_function(X, y)
cross_val_function(df, X, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ArtsN_2014   R-squared:                       0.643
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     51.10
# Date:                Wed, 23 Nov 2016   Prob (F-statistic):           3.11e-96
# Time:                        12:18:38   Log-Likelihood:                -3384.5
# No. Observations:                 500   AIC:                             6805.
# Df Residuals:                     482   BIC:                             6881.
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const              -43.2552     20.117     -2.150      0.032       -82.783    -3.728
# JobsN_1998          -0.0026      0.002     -1.325      0.186        -0.007     0.001
# ArtsN_1998           0.4944      0.038     12.904      0.000         0.419     0.570
# Traditionalistic   -12.7938      4.831     -2.648      0.008       -22.286    -3.302
# Self_Expressive      4.7740      3.063      1.559      0.120        -1.244    10.792
# Utilitarian          3.0075      1.694      1.775      0.077        -0.322     6.337
# Charismatic          5.4035      2.888      1.871      0.062        -0.272    11.079
# Egalitarian         -1.8676      2.691     -0.694      0.488        -7.155     3.420
# Neighborly           5.6332      4.581      1.230      0.219        -3.369    14.635
# Formality            6.6519      2.697      2.466      0.014         1.352    11.951
# Exhibitionism        2.4852      2.696      0.922      0.357        -2.812     7.782
# Glamorous           -5.0202      3.271     -1.535      0.126       -11.448     1.407
# Transgressive       -1.5851      2.336     -0.679      0.498        -6.174     3.004
# Rational            -0.3667      3.065     -0.120      0.905        -6.389     5.656
# Locality             5.6371      2.488      2.266      0.024         0.749    10.525
# State_Scenes       -16.8031      5.041     -3.333      0.001       -26.708    -6.899
# Corporateness       -1.0702      2.083     -0.514      0.608        -5.162     3.022
# Ethnicity            5.6330      4.946      1.139      0.255        -4.086    15.352
# ==============================================================================
# Omnibus:                      297.362   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14141.061
# Skew:                           1.874   Prob(JB):                         0.00
# Kurtosis:                      28.782   Cond. No.                     2.76e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 99582.3524445
# R2: 0.584738700776
# Model 2
# MSE: 51961.4168918
# R2: 0.634813105466
# Model 3
# MSE: 54442.3382211
# R2: 0.612633042074
# Model 4
# MSE: 42857.2494243
# R2: 0.636369599146
# Model 5
# MSE: 86049.4903056
# R2: 0.629532971086
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 66978.5694575
# Mean of R2 for all folds: 0.61961748371

# %% [markdown]
# And we see here that even though the R2 is high, most of the variables are not significant. So I run decision trees and random forests in order to see which variables are more important for the arts.

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### The Scenes variables

# %% [markdown]
# Here we look for the feature importances of the scenes variables for changes in the arts. So what traits helped for and increase or decrease in the number of arts jobs in a zip code?

# %%
# The decision tree function 

def decision_tree(X, y):
    # Creating the decision tree object 
    dt = DecisionTreeClassifier(criterion='entropy', random_state=4)
    
    # Fitting the variables 
    dt.fit(X, y)

    # Put the feature importances in a list
    feature_importances_array = dt.feature_importances_

    # Put the features themselves in a list
    features_array = X.columns.values 

    # Turn these into a Data Frame
    feature_importances_df = pd.DataFrame({'importances' : feature_importances_array,
                                           'features' : features_array})

    # Sort the feature importances highest to lowest
    return feature_importances_df.sort(columns='importances',ascending=False)

# %%
#Cross validation function for decision tree

def dt_cross_val(X, y):
    from sklearn.model_selection import cross_val_score

    # Get the cross validated accuracy score for each of three cross validation folds
    dt = DecisionTreeClassifier(criterion='entropy', random_state=4)
    dt_scores = cross_val_score(dt, X, y)

    # Take the mean of these scores
    print round(dt_scores.mean(), 5)

# %%
decision_tree(df[scenes], df['arts_change'])
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 7      Exhibitionism     0.169560
# 6          Formality     0.121241
# 11          Locality     0.108274
# 2        Utilitarian     0.076579
# 0   Traditionalistic     0.067897
# 13     Corporateness     0.059494
# 9      Transgressive     0.055105
# 1    Self_Expressive     0.053760
# 8          Glamorous     0.052706
# 3        Charismatic     0.043160
# 10          Rational     0.043002
# 5         Neighborly     0.042461
# 4        Egalitarian     0.039421
# 14         Ethnicity     0.038602
# 12      State_Scenes     0.028737

# %%
dt_cross_val(df[scenes], df['arts_change'])
# Out:
# 0.03384

# %%
decision_tree(df[scenes], df['ArtsN_2014'])
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 7      Exhibitionism     0.144530
# 4        Egalitarian     0.093471
# 11          Locality     0.086977
# 5         Neighborly     0.085997
# 13     Corporateness     0.085839
# 1    Self_Expressive     0.069304
# 2        Utilitarian     0.067724
# 8          Glamorous     0.060852
# 6          Formality     0.051354
# 9      Transgressive     0.050129
# 12      State_Scenes     0.046537
# 0   Traditionalistic     0.043683
# 14         Ethnicity     0.042949
# 10          Rational     0.040914
# 3        Charismatic     0.029739

# %%
dt_cross_val(df[scenes], df['ArtsN_2014'])
# Out:
# 0.03808

# %% [markdown]
# We see that exhibitionism is the most important zip code trait for both arts in 2014 and arts change. But for more changes to occur, the other traits are formality, locality, utilitarian. While the arts in 2014 are more influenced by egalitarian, locality, neighborly, corporateness traits.
#
#
# The cross validation score is very low, but it might be due to the diversity of the variables included in the analysis; that might be contradicting among each other.
#
# If we consider only the variables where there was increase in the arts, then we see that self-expressive, utilitarian, corporateness, ethnicity, and locality became more important for the arts.

# %%
# If we consider the arts changes that were positive and negative, the results might differ. 

# Defining the positive arts variables
positive_arts = df[df.arts_change > 0]

# Defining the negative arts variables
negative_arts = df[df.arts_change <= 0]

# %%
X = positive_arts[scenes]
y = positive_arts['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 1    Self_Expressive     0.138780
# 2        Utilitarian     0.094884
# 13     Corporateness     0.093569
# 14         Ethnicity     0.092340
# 11          Locality     0.092047
# 9      Transgressive     0.072939
# 8          Glamorous     0.070726
# 10          Rational     0.067538
# 4        Egalitarian     0.058883
# 12      State_Scenes     0.044346
# 6          Formality     0.043654
# 7      Exhibitionism     0.035626
# 5         Neighborly     0.034077
# 3        Charismatic     0.033683
# 0   Traditionalistic     0.026909

# %% [markdown]
# And if we compare to the zipcodes where the arts had a decrease, we see that ethnicity, transgressive, utilitarian, locality, and formality were the important traits.

# %%
X = negative_arts[scenes]
y = negative_arts['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 14         Ethnicity     0.138557
# 9      Transgressive     0.115751
# 2        Utilitarian     0.102640
# 11          Locality     0.094221
# 6          Formality     0.092916
# 10          Rational     0.082584
# 3        Charismatic     0.061379
# 13     Corporateness     0.055372
# 12      State_Scenes     0.048284
# 4        Egalitarian     0.044362
# 1    Self_Expressive     0.040850
# 7      Exhibitionism     0.036873
# 0   Traditionalistic     0.030571
# 8          Glamorous     0.030518
# 5         Neighborly     0.025122

# %% [markdown]
# In conclusion, we can say that the ethnicity, locality or utilitan wouldn't steer the arts in one way or another (because they are present on the top of the feature importances of both positive and negative arts), but that self-expression and corporateness is favorable for the arts, while transgressive and formality are unfavorable for the arts.

# %% [markdown]
# #### Visualizing decision tree
#
# The code to visualize the decision tree is below. However, we need a software called graphviz, and the decision tree is so large that it is impractical to paste it here.

# %%
# from sklearn.tree import export_graphviz

# export_graphviz(dt, out_file='tree5.dot')

# %% [markdown]
# ### Geolytics and core variables

# %% [markdown]
# On this analysis, we add the other control variables: the socio-economic variables, and habits. Conducting the same analysis as before.

# %%
X = df[geo_core]
y = df['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 7        pctsamehouse2k     0.103582
# 23          NonWhite_90     0.088946
# 4            medhhinc2k     0.069138
# 20              Pop2000     0.064631
# 10           pctchild2k     0.062505
# 16           pctdrove2k     0.062305
# 12        diversityfb2k     0.053372
# 13          pctrental2k     0.053028
# 5            meantrav2k     0.048437
# 9          pctmarried2k     0.047889
# 17            pctwalk2k     0.047483
# 21  CrimeRate1999county     0.033483
# 15            pctbike2k     0.029684
# 2       racediversity2k     0.029027
# 22              Democ92     0.027277
# 0              MedAge2k     0.024026
# 11           pctunemp2k     0.023576
# 6        medlengthres2k     0.020589
# 18          density2000     0.020330
# 3             medrent2k     0.018599
# 19   housingdensity2000     0.016728
# 14             pctpov2k     0.016655
# 1               pctba2k     0.013135
# 8           pctfemale2k     0.013034
# 24         CollProfLv90     0.012539

# %%
dt_cross_val(X, y)
# Out:
# 0.00783

# %% [markdown]
# Here we see that the most important traits are for people to be living in the same house for the last 5 years, the median income, population diversity and density. Again, the cross validation score is practically zero.

# %% [markdown]
# And now dividing the data into the positive and negative arts changes, we have that walkability, stability of households, and presence of children are favorable for the arts; while percent non white, percent rental, and median age helped for decreases in the arts.

# %%
X = positive_arts[geo_core]
y = positive_arts['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 7        pctsamehouse2k     0.126924
# 10           pctchild2k     0.102945
# 17            pctwalk2k     0.098586
# 11           pctunemp2k     0.067877
# 5            meantrav2k     0.064695
# 4            medhhinc2k     0.048586
# 22              Democ92     0.046535
# 0              MedAge2k     0.044467
# 20              Pop2000     0.043938
# 9          pctmarried2k     0.043178
# 23          NonWhite_90     0.037834
# 3             medrent2k     0.034849
# 15            pctbike2k     0.033480
# 12        diversityfb2k     0.033309
# 18          density2000     0.028261
# 14             pctpov2k     0.022921
# 13          pctrental2k     0.017140
# 21  CrimeRate1999county     0.016005
# 2       racediversity2k     0.015397
# 8           pctfemale2k     0.014530
# 19   housingdensity2000     0.014197
# 6        medlengthres2k     0.012813
# 16           pctdrove2k     0.012773
# 1               pctba2k     0.011350
# 24         CollProfLv90     0.007409

# %%
dt_cross_val(X, y)
# Out:
# 0.0412

# %%
X = negative_arts[geo_core]
y = negative_arts['arts_change']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 23          NonWhite_90     0.166491
# 13          pctrental2k     0.087253
# 4            medhhinc2k     0.081697
# 15            pctbike2k     0.072098
# 24         CollProfLv90     0.067978
# 21  CrimeRate1999county     0.060351
# 3             medrent2k     0.050982
# 17            pctwalk2k     0.048024
# 12        diversityfb2k     0.039309
# 7        pctsamehouse2k     0.032614
# 5            meantrav2k     0.032355
# 18          density2000     0.027222
# 20              Pop2000     0.026925
# 8           pctfemale2k     0.026756
# 0              MedAge2k     0.026725
# 16           pctdrove2k     0.022394
# 11           pctunemp2k     0.021773
# 1               pctba2k     0.019480
# 14             pctpov2k     0.018539
# 2       racediversity2k     0.017652
# 10           pctchild2k     0.014345
# 6        medlengthres2k     0.011252
# 22              Democ92     0.010500
# 19   housingdensity2000     0.009517
# 9          pctmarried2k     0.007768

# %%
dt_cross_val(X, y)
# Out:
# 0.0906

# %% [markdown]
# ### Arts and jobs variables
#
# Here we look at which years or variables were more important to attracting the arts. Is arts what attract the arts, or do jobs help too? In this case, I use the Arts in 2014 as dependent variable, as it is the outcome, instead of the arts change.

# %%
X = df[arts_jobs]
y = df['ArtsN_2014']

decision_tree(X, y)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#       features  importances
# 30  ArtsN_2013     0.434073
# 28  ArtsN_2012     0.065460
# 31  JobsN_2013     0.041972
# 14  ArtsN_2005     0.033362
# 24  ArtsN_2010     0.030493
# 18  ArtsN_2007     0.026790
# 7   JobsN_2001     0.025269
# 3   JobsN_1999     0.024971
# 12  ArtsN_2004     0.024515
# 11  JobsN_2003     0.023258
# 16  ArtsN_2006     0.022849
# 26  ArtsN_2011     0.020655
# 29  JobsN_2012     0.019723
# 20  ArtsN_2008     0.019050
# 6   ArtsN_2001     0.018712
# 0   ArtsN_1998     0.018164
# 21  JobsN_2008     0.017295
# 4   ArtsN_2000     0.015578
# 10  ArtsN_2003     0.014508
# 9   JobsN_2002     0.014188
# 8   ArtsN_2002     0.012944
# 2   ArtsN_1999     0.012593
# 17  JobsN_2006     0.012572
# 19  JobsN_2007     0.009454
# 25  JobsN_2010     0.008515
# 13  JobsN_2004     0.007245
# 23  JobsN_2009     0.006970
# 1   JobsN_1998     0.006899
# 22  ArtsN_2009     0.004513
# 27  JobsN_2011     0.004513
# 5   JobsN_2000     0.001616
# 15  JobsN_2005     0.001281

# %% [markdown]
# Of course arts in 2013 would be of the highest impact for arts in 2014, however, it is surprising to see that arts in 2005, 2010, and 2007 are so much closer to the top, as well as jobs in 2001 and 1999.

# %% [markdown]
# ## Random Forest

# %% [markdown]
# Instead of just a decision tree, we now try the random forest algorithm.

# %%
# Random forest function

def random_forest(X, y): 

    from sklearn.ensemble import RandomForestClassifier
    
    rf = RandomForestClassifier(n_estimators = 1000, class_weight='balanced')
    
    # Get the cross validated accuracy score for each of three cross validation folds (one line below):
    rf_scores = cross_val_score(rf, X, y)

    # Add one line to simply print out the resulting scores:
    print str(rf_scores)

    # Get the mean of these scores (one line below):
    print "mean of cross validation scores: " + str(round(rf_scores.mean(), 3))

    rf.fit(X, y)
    fi = rf.feature_importances_
    feat = X.columns.values
    feat_df = pd.DataFrame({"importances": fi,
                            "features": feat})
    return feat_df.sort("importances", ascending=False)

# %%
X = df[scenes]
y = df['arts_change']

random_forest(X, y)
# Out:
# [ 0.00664452  0.024       0.02702703]
# mean of cross validation scores: 0.019
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 13     Corporateness     0.071175
# 2        Utilitarian     0.069458
# 11          Locality     0.069236
# 9      Transgressive     0.068970
# 6          Formality     0.067587
# 8          Glamorous     0.067251
# 10          Rational     0.066332
# 3        Charismatic     0.066269
# 7      Exhibitionism     0.065930
# 4        Egalitarian     0.065909
# 1    Self_Expressive     0.065812
# 12      State_Scenes     0.064283
# 0   Traditionalistic     0.064229
# 5         Neighborly     0.064020
# 14         Ethnicity     0.063538

# %%
X = positive_arts[scenes]
y = positive_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.          0.01408451  0.05263158]
# mean of cross validation scores: 0.022
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 2        Utilitarian     0.070027
# 11          Locality     0.069498
# 13     Corporateness     0.069410
# 6          Formality     0.067593
# 9      Transgressive     0.067046
# 12      State_Scenes     0.066753
# 1    Self_Expressive     0.066562
# 8          Glamorous     0.066109
# 3        Charismatic     0.066094
# 10          Rational     0.066084
# 4        Egalitarian     0.065342
# 5         Neighborly     0.065249
# 0   Traditionalistic     0.065104
# 7      Exhibitionism     0.064641
# 14         Ethnicity     0.064487

# %%
X = negative_arts[scenes]
y = negative_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.03361345  0.05555556  0.13888889]
# mean of cross validation scores: 0.076
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#             features  importances
# 9      Transgressive     0.071853
# 2        Utilitarian     0.069383
# 11          Locality     0.069215
# 13     Corporateness     0.069177
# 1    Self_Expressive     0.068074
# 8          Glamorous     0.067168
# 10          Rational     0.066591
# 7      Exhibitionism     0.066336
# 6          Formality     0.065941
# 4        Egalitarian     0.065404
# 0   Traditionalistic     0.064762
# 12      State_Scenes     0.064508
# 3        Charismatic     0.064463
# 14         Ethnicity     0.064208
# 5         Neighborly     0.062916

# %% [markdown]
# ### For the other variables

# %%
X = df[geo_core]
y = df['arts_change']

random_forest(X, y)
# Out:
# [ 0.01328904  0.032       0.12162162]
# mean of cross validation scores: 0.056
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 20              Pop2000     0.049537
# 12        diversityfb2k     0.048270
# 5            meantrav2k     0.047483
# 7        pctsamehouse2k     0.045266
# 9          pctmarried2k     0.042881
# 2       racediversity2k     0.042716
# 10           pctchild2k     0.042167
# 4            medhhinc2k     0.042135
# 24         CollProfLv90     0.041781
# 23          NonWhite_90     0.041453
# 13          pctrental2k     0.041423
# 14             pctpov2k     0.041301
# 22              Democ92     0.041129
# 16           pctdrove2k     0.040794
# 1               pctba2k     0.040075
# 3             medrent2k     0.038578
# 0              MedAge2k     0.038211
# 8           pctfemale2k     0.037609
# 15            pctbike2k     0.037267
# 17            pctwalk2k     0.037083
# 21  CrimeRate1999county     0.036903
# 11           pctunemp2k     0.035570
# 19   housingdensity2000     0.033256
# 18          density2000     0.032641
# 6        medlengthres2k     0.024470

# %%
X = positive_arts[geo_core]
y = positive_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.02197802  0.          0.05263158]
# mean of cross validation scores: 0.025
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 5            meantrav2k     0.054100
# 20              Pop2000     0.046630
# 10           pctchild2k     0.044300
# 7        pctsamehouse2k     0.044080
# 9          pctmarried2k     0.043835
# 14             pctpov2k     0.042868
# 12        diversityfb2k     0.042293
# 24         CollProfLv90     0.042181
# 4            medhhinc2k     0.042157
# 22              Democ92     0.042040
# 13          pctrental2k     0.040925
# 2       racediversity2k     0.040334
# 16           pctdrove2k     0.040171
# 23          NonWhite_90     0.040039
# 1               pctba2k     0.039803
# 17            pctwalk2k     0.039008
# 3             medrent2k     0.038965
# 8           pctfemale2k     0.038322
# 21  CrimeRate1999county     0.038262
# 0              MedAge2k     0.038198
# 11           pctunemp2k     0.036578
# 15            pctbike2k     0.035242
# 19   housingdensity2000     0.033093
# 18          density2000     0.031931
# 6        medlengthres2k     0.024646

# %%
X = negative_arts[geo_core]
y = negative_arts['arts_change']

random_forest(X, y)
# Out:
# [ 0.03361345  0.09259259  0.22222222]
# mean of cross validation scores: 0.116
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 12        diversityfb2k     0.053297
# 7        pctsamehouse2k     0.052271
# 20              Pop2000     0.052030
# 13          pctrental2k     0.044212
# 16           pctdrove2k     0.044020
# 2       racediversity2k     0.043950
# 0              MedAge2k     0.043837
# 9          pctmarried2k     0.042204
# 5            meantrav2k     0.041405
# 10           pctchild2k     0.040736
# 23          NonWhite_90     0.040480
# 1               pctba2k     0.040183
# 8           pctfemale2k     0.039186
# 24         CollProfLv90     0.038790
# 15            pctbike2k     0.038717
# 22              Democ92     0.038540
# 4            medhhinc2k     0.037396
# 14             pctpov2k     0.036080
# 11           pctunemp2k     0.035441
# 21  CrimeRate1999county     0.034843
# 3             medrent2k     0.034091
# 18          density2000     0.033950
# 19   housingdensity2000     0.033728
# 17            pctwalk2k     0.033385
# 6        medlengthres2k     0.027230

# %% [markdown]
# ### For the years before 2014

# %%
# Analysis for how the years preceeding affected 2014. 

X = df[arts_jobs]
y = df['ArtsN_2014']

random_forest(X, y)
# Out:
# [ 0.05102041  0.08661417  0.21518987]
# mean of cross validation scores: 0.118
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#       features  importances
# 30  ArtsN_2013     0.045722
# 28  ArtsN_2012     0.041678
# 26  ArtsN_2011     0.038313
# 24  ArtsN_2010     0.036244
# 8   ArtsN_2002     0.036189
# 18  ArtsN_2007     0.036027
# 16  ArtsN_2006     0.035227
# 20  ArtsN_2008     0.035085
# 22  ArtsN_2009     0.034687
# 0   ArtsN_1998     0.033989
# 4   ArtsN_2000     0.033939
# 2   ArtsN_1999     0.033541
# 12  ArtsN_2004     0.033298
# 14  ArtsN_2005     0.033077
# 10  ArtsN_2003     0.033010
# 6   ArtsN_2001     0.032429
# 29  JobsN_2012     0.029200
# 1   JobsN_1998     0.028806
# 31  JobsN_2013     0.028729
# 3   JobsN_1999     0.028010
# 9   JobsN_2002     0.027929
# 27  JobsN_2011     0.027363
# 25  JobsN_2010     0.026491
# 5   JobsN_2000     0.026454
# 7   JobsN_2001     0.026413
# 23  JobsN_2009     0.025806
# 21  JobsN_2008     0.025780
# 19  JobsN_2007     0.025549
# 11  JobsN_2003     0.025505
# 15  JobsN_2005     0.025367
# 17  JobsN_2006     0.025346
# 13  JobsN_2004     0.024798

# %% [markdown]
# ### For all the variables together
#
# In this analysis, we try all the variables together, against arts in 2014.
#
# As we can see from the feature importances, Arts in 2013 is the highest, followed by presence of children, mean travel time, arts in 2012, race diversity, and rent twice. This shows that previous presence of arts, as well as diversity of race and age are important factors for the arts in 2014. However, the scores are much lower than in the other analyses.

# %%
# Analysis with all the variables together, except 2014. 

X = df[all_var]
y = df['ArtsN_2014']

random_forest(X, y)
# Out:
# [ 0.05442177  0.07874016  0.11392405]
# mean of cross validation scores: 0.082
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                features  importances
# 70           ArtsN_2013     0.022264
# 25           meantrav2k     0.020079
# 68           ArtsN_2012     0.019705
# 30           pctchild2k     0.019512
# 36           pctdrove2k     0.019164
# 22      racediversity2k     0.018775
# 34             pctpov2k     0.018711
# 33          pctrental2k     0.018484
# 1   CrimeRate1999county     0.018158
# 29         pctmarried2k     0.017858
# 27       pctsamehouse2k     0.017855
# 28          pctfemale2k     0.017640
# 37            pctwalk2k     0.017586
# 32        diversityfb2k     0.017545
# 31           pctunemp2k     0.016895
# 20             MedAge2k     0.016886
# 66           ArtsN_2011     0.016831
# 23            medrent2k     0.016504
# 24           medhhinc2k     0.016295
# 0               Pop2000     0.016121
# 48           ArtsN_2002     0.016121
# 21              pctba2k     0.015995
# 64           ArtsN_2010     0.015853
# 4          CollProfLv90     0.015773
# 38          density2000     0.015704
# 58           ArtsN_2007     0.015686
# 56           ArtsN_2006     0.015480
# 2               Democ92     0.015388
# 40           ArtsN_1998     0.015061
# 62           ArtsN_2009     0.014992
# ..                  ...          ...
# 49           JobsN_2002     0.012207
# 43           JobsN_1999     0.011896
# 26       medlengthres2k     0.011840
# 71           JobsN_2013     0.011761
# 67           JobsN_2011     0.011651
# 65           JobsN_2010     0.011309
# 57           JobsN_2006     0.011173
# 45           JobsN_2000     0.011078
# 47           JobsN_2001     0.011071
# 63           JobsN_2009     0.010884
# 51           JobsN_2003     0.010752
# 61           JobsN_2008     0.010740
# 59           JobsN_2007     0.010633
# 7           Utilitarian     0.010305
# 16             Locality     0.010261
# 53           JobsN_2004     0.010211
# 18        Corporateness     0.009904
# 55           JobsN_2005     0.009837
# 12        Exhibitionism     0.009834
# 11            Formality     0.009668
# 13            Glamorous     0.009638
# 14        Transgressive     0.009625
# 6       Self_Expressive     0.009614
# 8           Charismatic     0.009474
# 19            Ethnicity     0.009474
# 17         State_Scenes     0.009394
# 15             Rational     0.009320
# 9           Egalitarian     0.009163
# 5      Traditionalistic     0.009121
# 10           Neighborly     0.008766
#
# [72 rows x 2 columns]

# %% [markdown]
# ## Clustering Analysis

# %%
def set_colors(labels, colors='rgbykcm'):
    colored_labels = []
    for label in labels:
        colored_labels.append(colors[label])
    return colored_labels

# %%
plt.scatter(df['Utilitarian'], df['ArtsN_2014'])
plt.show()

# %%
# Fit a k-means estimator
estimator = KMeans(n_clusters=3)
X = df[["Exhibitionism", "ArtsN_2014"]]
estimator.fit(X)
# Clusters are given in the labels_ attribute
labels = estimator.labels_
# Plot the data
colors = set_colors(labels)
plt.scatter(df["Exhibitionism"], df["ArtsN_2014"], c=colors)
plt.xlabel("Exhibitionism")
plt.ylabel("ArtsN_2014")
plt.show()

# %% [markdown]
# We see a division into three distinct groups, but by size of the zip code, and one thin outlier group on the top.

# %% [markdown]
# ## DBSCAN Clustering

# %%
df = pd.read_csv("nomiss_sample.csv")

# sns.clustermap(df[["JobsN_2014", "ArtsN_2014"]], method="complete")

# %%
estimator = KMeans(n_clusters=4)

X = df[all_var]

estimator.fit(X)

# Clusters are given in the labels_ attribute
labels = estimator.labels_

colors = set_colors(labels)
plt.scatter(df['Exhibitionism'], df['ArtsN_2014'], c=colors)
plt.xlabel("Exhibitionism")
plt.ylabel("ArtsN_2014")
plt.show()

# %% [markdown]
# In this cluster, the colors are mixed together, because all the variables are considered in the analysis.

# %%
estimator = KMeans(n_clusters=3)
X = df[['Traditionalistic','Self_Expressive', 'Utilitarian', 'Charismatic', 'Egalitarian', 'Neighborly', 'Formality',
        'Exhibitionism', 'Glamorous', 'Transgressive', 'Rational', 'Locality', 'State_Scenes', 
'Corporateness', 'Ethnicity', 'zip']]
estimator.fit(X)
# Clusters are given in the labels_ attribute
labels = estimator.labels_

colors = set_colors(labels)
plt.scatter(df['zip'], df['ArtsN_2014'], c=colors)
plt.xlabel("zip")
plt.ylabel("ArtsN_2014")
plt.show()

# %% [markdown]
# In this last clustering, we see that the colors are divided by zip code number, into an East, Central, and West division of the country.
#
# As we can see from both plots, cluster analyses are not very helpful on defining patterns in the data. The dots get mixed into each other; and only the zip code is able to set them apart in different groups.

# %% [markdown]
# ## Autocorrelation

# %%
# Loading the data file in the LONG format. (Created in R)
df_long = pd.read_csv("nomisslong_sample.csv")

# %%
# How does autocorrelation vary in different ranges of years? For arts.

period_lag = range(1, 15)
auto_corrs_list = []
for x in period_lag:
    y = df_long['ArtsN'].autocorr(lag=x)
    auto_corrs_list.append(y)
    print x, y
# Out:
# 1 -0.072502636837
# 2 -0.019333784748
# 3 -0.0178478604447
# 4 0.0309645387751
# 5 0.0216541111677
# 6 -0.00889121629323
# 7 -0.0186960378347
# 8 -0.0173698347505
# 9 0.024672532821
# 10 -0.0286070226386
# 11 0.0576784262754
# 12 -0.0554090035146
# 13 0.00399652061826
# 14 0.113967007957

# %%
plt.plot(period_lag, auto_corrs_list)

# %%
# Testing autocorrelation for the lag between all time periods. For jobs. 

period_lag = range(1, 15)
auto_corrs_list = []
for x in period_lag:
    y = df_long['JobsN'].autocorr(lag=x)
    auto_corrs_list.append(y)
    print x, y
# Out:
# 1 -0.0557095613078
# 2 -0.000309940872803
# 3 -0.034347826758
# 4 0.0749254779576
# 5 0.0873817495758
# 6 -0.0439491889978
# 7 0.00535665384213
# 8 -0.0621313993994
# 9 0.0848987354346
# 10 0.0114462365266
# 11 0.0527922117835
# 12 -0.0312721345734
# 13 -0.00816189407962
# 14 0.0561153772573

# %%
plt.plot(period_lag, auto_corrs_list)

# %% [markdown]
# One issue that was worrisome was autocorrelation between the years of analysis.
# By running the autocorrelation analysis with the different lags of years, we see that the autocorrelation is close to zero, confirming that the data is good to be run this way.

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Raschka, Sebastian. Python Machine Learning. Packt Publishing, 2015. <br/>
# Chapter 5. Compressing data via dimensionality reduction.

# %%
#Loading the datafile. This is just a sample of the data. N=500
df = pd.read_csv("nomiss_sample.csv")

# Dropping unnecessary variables (Some string variables too, like names of the zip code location)
df.drop(['pctba90', 'racediversity90', 'medrent90', 'medhhinc90', 'meantrav90', 'meanlengthres90', 'pctsamehouse90',
'pctfemale90', 'pctmarried90', 'pctchild90', 'pctunemp90', 'diversityanc90', 'pctrental90', 'pctpov90', 'pctbike90',
'pctdrove90', 'pctwalk90', 'density1990', 'housingdensity1990', 'Pop1990', 'Unnamed: 0','JobsT_1998', 'ArtsW_1998', 'JobsW_1998', 
'ArtSupport_1998', 'JobsT_1999', 'ArtsW_1999', 'JobsW_1999', 'ArtSupport_1999', 'JobsT_2000', 'ArtsW_2000', 'JobsW_2000',
 'ArtSupport_2000', 'JobsT_2001', 'ArtsW_2001', 'JobsW_2001', 'ArtSupport_2001', 'JobsT_2002', 'ArtsW_2002', 'JobsW_2002',
 'ArtSupport_2002', 'JobsT_2003', 'ArtsW_2003', 'JobsW_2003', 'ArtSupport_2003', 'JobsT_2004', 'ArtsW_2004', 'JobsW_2004',
 'ArtSupport_2004', 'JobsT_2005', 'ArtsW_2005', 'JobsW_2005', 'ArtSupport_2005', 'JobsT_2006', 'ArtsW_2006', 'JobsW_2006',
 'ArtSupport_2006', 'JobsT_2007', 'ArtsW_2007', 'JobsW_2007', 'ArtSupport_2007', 'JobsT_2008', 'ArtsW_2008', 'JobsW_2008',
 'ArtSupport_2008', 'JobsT_2009', 'ArtsW_2009', 'JobsW_2009', 'ArtSupport_2009', 'JobsT_2010', 'ArtsW_2010', 'JobsW_2010',
 'ArtSupport_2010', 'JobsT_2011', 'ArtsW_2011', 'JobsW_2011', 'ArtSupport_2011', 'JobsT_2012', 'ArtsW_2012', 'JobsW_2012',
 'ArtSupport_2012', 'JobsT_2013', 'ArtsW_2013', 'JobsW_2013', 'ArtSupport_2013', 'JobsT_2014', 'ArtsW_2014',
 'JobsW_2014', 'ArtSupport_2014', 'ARTGOSLG98', 'City', 'State', 'Location', 'zipcode'], axis=1, inplace=True)

# Creating a change variables for the arts
df['arts_change'] = df['ArtsN_2014'] - df['ArtsN_1998']

# %%
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler

#Splitting the data into train and test datasets.

X, y = df.iloc[:, 1:].values, df.iloc[:, 0].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.fit_transform(X_test)

# %%
# Calculating the eigen values 

cov_mat = np.cov(X_train_std.T)
eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)
print('\nEigenvalues \n%s' % eigen_vals)
# Out:
# Eigenvalues
# [  3.84759847e+01   6.64879858e+00   5.74122620e+00   4.21196787e+00
#    3.28637743e+00   3.17158218e+00   2.11821397e+00   1.86450735e+00
#    1.32389618e+00   1.07431379e+00   8.67753716e-01   8.18758540e-01
#    7.69169468e-01   6.40226090e-01   5.83889447e-01   5.10998281e-01
#    4.90045029e-01   4.33421902e-01   3.71820759e-01   3.29093320e-01
#    3.15173645e-01   2.66389623e-01   2.26618224e-01   1.89747378e-01
#    1.61724436e-01   1.57061716e-01   1.48490472e-01   1.28953546e-01
#    1.04307561e-01   1.01508412e-01   9.64751684e-02   8.12232376e-02
#    7.82863208e-02   6.26708675e-02   6.90351288e-02   4.73328390e-02
#    3.35180860e-02   2.34682315e-02   2.98467911e-02   2.88023694e-02
#    1.87975663e-02   1.47418646e-02   1.36597106e-02   1.15071475e-02
#    1.11376125e-02   1.01597971e-02   8.86414790e-03   7.88751460e-03
#    7.10861083e-03   4.70237038e-03   4.56230501e-03   3.90741973e-03
#    3.20786696e-03   2.83740019e-03   2.26716814e-03   1.80020042e-03
#    1.61717948e-03   1.36424519e-03   1.17570059e-03   1.09819220e-03
#    7.97995046e-04   6.47866750e-04   4.81536223e-04   1.62500952e-04
#    1.28206492e-04   1.08429129e-04   8.38087845e-05   1.17606959e-15
#    7.65671074e-05   1.05569506e-05   1.59174224e-05   2.07443863e-05
#    3.10810476e-05   3.51997489e-05   4.26397832e-05   3.90662778e-05]

# %%
#Plotting the eigenpairs

tot = sum(eigen_vals)
var_exp = [(i / tot) for i in sorted(eigen_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
plt.bar(range(1,77), var_exp, alpha=0.5, align='center', label='individual explained variance')
plt.step(range(1,77), cum_var_exp, where='mid', label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# The first principal component explains about 50% of the variance, and the other 50% is explained by the other variables in the dataset. But what is that thing?

# %%
#Sorting eigenpairs on descending order

eigen_pairs =[(np.abs(eigen_vals[i]),eigen_vecs[:,i]) 
              for i in range(len(eigen_vals))]
eigen_pairs.sort(reverse=True)

# %%
# Collect the two eigenvectors that correspond to the two largest values.

w= np.hstack((eigen_pairs[0][1][:, np.newaxis], eigen_pairs[1][1][:, np.newaxis]))
print('Matrix W:\n',w)
# Out:
# ('Matrix W:\n', array([[-0.10153017, -0.12168904],
#        [-0.1452461 ,  0.10469681],
#        [-0.10663573, -0.1152029 ],
#        [-0.14524148,  0.10426139],
#        [-0.10233959, -0.12887076],
#        [-0.1468721 ,  0.09764909],
#        [-0.1035983 , -0.15946119],
#        [-0.1471814 ,  0.09000591],
#        [-0.10522959, -0.14987108],
#        [-0.14701094,  0.08904838],
#        [-0.12275143, -0.14052805],
#        [-0.14576976,  0.09146686],
#        [-0.13160527, -0.12525244],
#        [-0.14470504,  0.09493347],
#        [-0.1344431 , -0.13070369],
#        [-0.14511037,  0.09340443],
#        [-0.13200463, -0.13984694],
#        [-0.14467974,  0.0959579 ],
#        [-0.13361894, -0.1293093 ],
#        [-0.1446317 ,  0.08698916],
#        [-0.12216518, -0.1528691 ],
#        [-0.14446192,  0.08577544],
#        [-0.11871437, -0.15991274],
#        [-0.14495832,  0.08265665],
#        [-0.11833748, -0.16120748],
#        [-0.14517079,  0.08403987],
#        [-0.11841197, -0.15175495],
#        [-0.14578556,  0.07972293],
#        [-0.12062932, -0.15462555],
#        [-0.1446611 ,  0.07873441],
#        [-0.12020206, -0.15059964],
#        [-0.14459965,  0.07188065],
#        [-0.12179672, -0.1484931 ],
#        [-0.14507582,  0.06842596],
#        [ 0.05253789, -0.15067037],
#        [-0.04864652, -0.24279423],
#        [-0.06022814,  0.17294514],
#        [-0.04171794, -0.19146614],
#        [-0.01060285, -0.24520858],
#        [ 0.0193328 , -0.0506011 ],
#        [ 0.07092486, -0.09329976],
#        [ 0.07726609, -0.07148514],
#        [ 0.01585704,  0.0061772 ],
#        [ 0.05798076, -0.14094095],
#        [ 0.02220319,  0.01268152],
#        [-0.0144976 ,  0.1859166 ],
#        [-0.01392357, -0.11427699],
#        [-0.07192248,  0.15843044],
#        [-0.022179  ,  0.21513926],
#        [-0.05495201,  0.02137276],
#        [ 0.03095155,  0.03553493],
#        [-0.02078215, -0.04706394],
#        [-0.04603401,  0.1026652 ],
#        [-0.04520921,  0.09153505],
#        [-0.09985542,  0.14604728],
#        [-0.0443746 , -0.11701507],
#        [-0.00117157, -0.01325293],
#        [-0.05405998,  0.19733671],
#        [-0.05226766, -0.21725967],
#        [-0.04303173,  0.09071824],
#        [-0.15025908,  0.00690544],
#        [-0.15032308,  0.00542269],
#        [-0.15086818,  0.00846806],
#        [-0.15043947,  0.00570968],
#        [-0.15047952,  0.00822415],
#        [-0.15030633,  0.00665338],
#        [-0.15053131,  0.00605239],
#        [-0.15022277,  0.00689577],
#        [-0.15040372,  0.00587148],
#        [-0.15043543,  0.00529659],
#        [-0.15048375,  0.00619534],
#        [-0.15018504,  0.00574173],
#        [-0.15030123,  0.00722039],
#        [-0.15051645,  0.00723469],
#        [-0.15025374,  0.00746508],
#        [-0.02671476, -0.03469913]]))

# %%
X_train_std[0].dot(w)
X_train_pca = X_train_std.dot(w)

# %%
colors = ['r', 'b', 'g']
markers = ['s', 'x', 'o']
for l, c, m in zip(np.unique(y_train), colors, markers):
    plt.scatter(X_train_pca[y_train==l, 0],
                X_train_pca[y_train==l, 1], 
                c=c, label=l, marker=m)
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# This PCA analysis did not show us much.

# %% [markdown]
# ### PCA on scikit-learn

# %%
from matplotlib.colors import ListedColormap
def plot_decision_regions(X, y, classifier, resolution=0.02):
    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
    np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    # plot class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
        alpha=0.8, c=cmap(idx), marker=markers[idx], label=cl)

# %%
### Seems right, but this almost exploded my computer!!! 

from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
lr = LogisticRegression()
X_train_pca = pca.fit_transform(X_train_std)

X_test_pca = pca.transform(X_test_std)


lr.fit(X_train_pca, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# This part takes about 30 minutes to run, and show an error, and a clustering plot that says very little. 
# IndexError: tuple index out of range

plot_decision_regions(X_train_pca, y_train, classifier=lr)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(loc='lower left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-206-db994c31b2b3> in <module>()
#       2 # IndexError: tuple index out of range
#       3
# ----> 4 plot_decision_regions(X_train_pca, y_train, classifier=lr)
#       5 plt.xlabel('PC1')
#       6 plt.ylabel('PC2')
#
# <ipython-input-204-6a353d85856b> in plot_decision_regions(X, y, classifier, resolution)
#      18     for idx, cl in enumerate(np.unique(y)):
#      19         plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
# ---> 20         alpha=0.8, c=cmap(idx), marker=markers[idx], label=cl)
#
# IndexError: tuple index out of range

# %% [markdown]
# ## Time Series Analysis

# %%
# Loading the data file in the LONG format. (Created in R)
df_long = pd.read_csv("nomisslong_sample.csv")

df_long['Total'] = df_long['ArtsN'] + df_long['JobsN']

# %%
df_long.head()
# Out:
#    Unnamed: 0    zip  MedAge2k    pctba2k    pctba90  racediversity2k  \
# 0  84124.1998  84124      37.4  42.130080  10.029895         0.160963
# 1   6239.1998   6239      36.4  13.127827  13.097893         0.145565
# 2  48236.1998  48236      42.3  55.610538  48.767123         0.123786
# 3  53203.1998  53203      34.9  60.269360  27.821522         0.374926
# 4  33917.1998  33917      52.4  13.231327  29.408242         0.099343
#
#    racediversity90  medrent2k  medrent90  medhhinc2k  ...    Corporateness  \
# 0         0.151323        699        483       55032  ...       397.038462
# 1         0.089482        520        505       39894  ...       249.696970
# 2         0.060418        812        509       82567  ...       918.470588
# 3         0.514221        788        360       50875  ...       762.612500
# 4         0.054643        569        590       33120  ...       173.740385
#
#     Ethnicity  time  JobsT  ArtsN  ArtsW  JobsN  JobsW  ArtSupport  Total
# 0  368.423077  1998   8713    123    688   8590   8025         565   8713
# 1  240.000000  1998   2861     13    170   2848   2691         157   2861
# 2  883.647059  1998  14878    312   1553  14566  13325        1241  14878
# 3  728.650000  1998  18751    379   3623  18372  15128        3244  18751
# 4  169.903846  1998   2604     53    193   2551   2411         140   2604
#
# [5 rows x 76 columns]

# %%
# How to make pandas understand that this is a years column so that I can use the resampling, and be sure it is using 
# year, not zip code.

# Trying with period objects.
df_long["time"] = pd.Period(df_long["time"], freq="a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-a9340d6fb75d> in <module>()
#       2 # year, not zip code.
#       3
# ----> 4 df_long["time"] = pd.Period(df_long["time"], freq="a")
#
# pandas/src/period.pyx in pandas._period.Period.__init__ (pandas/src/period.c:11369)()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __hash__(self)
#     799     def __hash__(self):
#     800         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 801                         ' hashed'.format(self.__class__.__name__))
#     802
#     803     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %% [markdown]
# Trying to make the time column be understood as year, but I can't! Any plot that I make will show by zip code, not by time. How to resample in this case?

# %%
# If not specified, the graph showss how arts varies per zip code. 

df_long['ArtsN'].plot()

# %% [markdown]
# There is no clear seasonality between the years, in either arts or jobs. But how can I improve these graphs?

# %%
# If not specified, the graph showss how arts varies per zip code. 

X = df_long['time']
y = df_long['ArtsN']

plt.plot(X, y)

# %% [markdown]
# How can I improve this graph too?
